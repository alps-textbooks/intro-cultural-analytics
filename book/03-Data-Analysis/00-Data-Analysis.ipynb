# %% [markdown]
# # Data Analysis (Pandas)

# %% [markdown]
# This series of lessons will focus on [Pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html), a powerful Python library for working with tabular data like CSV files.

# %% [markdown]
# - [Pandas Basics — Part 1](01-Pandas-Basics-Part1.ipynb)
# - [Pandas Basics — Part 2](02-Pandas-Basics-Part2.ipynb)
# - [Pandas Basics — Part 3](03-Pandas-Basics-Part3.ipynb)
# - [Pandas — Merge Datasets](04-Pandas-Merge-Datasets.ipynb)
