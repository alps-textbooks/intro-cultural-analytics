# %% [markdown]
# ## Text Analysis

# %% [markdown]
# This series of lessons will focus on text analyis methods:

# %% [markdown]
# - [Working in Languages Beyond English](01-Multilingual-Text-Analysis.ipynb)
# - [Term-Frequency Inverse Document Frequency](01-TF-IDF.ipynb)
# - [Sentiment Analysis](04-Sentiment-Analysis.ipynb)
# - [Topic Modeling](05-Topic-Modeling.ipynb)
# - [Named Entity Recognition](12-Named-Entity-Recognition.ipynb)
# - [Part-of-Speech Tagging](13-POS-Keywords.ipynb)
