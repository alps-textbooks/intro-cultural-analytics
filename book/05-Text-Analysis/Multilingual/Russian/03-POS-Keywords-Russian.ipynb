# %% [markdown]
# # Part-of-Speech Tagging for Russian

# %% [markdown]
# :::{note}
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# :::

# %% [markdown]
# In this lesson, we're going to learn about the textual analysis methods *part-of-speech tagging* and *keyword extraction* for Russian-language texts. These methods will help us computationally parse sentences and better understand words in context.

# %% [markdown]
# ---

# %% [markdown]
# ## spaCy and Natural Language Processing (NLP)

# %% [markdown]
# To computationally identify parts of speech, we're going to use the natural language processing library spaCy. For a more extensive introduction to NLP and spaCy, see the previous lesson.
#
# To parse sentences, spaCy relies on machine learning models that were trained on large amounts of labeled text data. If you've used the preprocessing or named entity recognition notebooks for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ## Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.
#
# Russian models are only available starting in spaCy 3.0.
#
# If you run into errors because spaCy 2.x is installed, you can run `!pip uninstall spacy -y` first, then run the cell below.

# %%
# %pip install -U spacy>=3.0

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

# %% [markdown]
# We're also going to import the `Counter` module for counting nouns, verbs, adjectives, etc., and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ## Download Language Model

# %% [markdown]
# Next we need to download the Russian-language model (`ru_core_news_md`), which will be processing and making predictions about our texts. You can read more about the corpus it was trained on, on the [spaCy model page](https://spacy.io/models/ru). You can download the `ru_core_news_md` model by running the cell below:

# %%
# ALPS unsupported shell command: !python -m spacy download ru_core_news_md

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Russian, Italian, Dutch, Greek, Norwegian, and Lithuanian*.
#
# *spaCy offers language and tokenization support for other language via external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean.*

# %% [markdown]
# ## Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('ru_core_news_md')

# %% [markdown]
# ## Create a Processed spaCy Document

# %% [markdown]
# Whenever we use spaCy, our first step will be to create a processed spaCy `document` with the loaded NLP model `nlp()`. Most of the heavy NLP lifting is done in this line of code. After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.

# %%
filepath = '../texts/ru.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## spaCy Part-of-Speech Tagging
# The tags that spaCy uses for part-of-speech are based on work done by [Universal Dependencies](https://universaldependencies.org/), an effort to create a set of part-of-speech tags that work across many different languages. Texts from various languages are annotated using this common set of tags, and contributed to a common repository that can be used to train models like spaCy.
#
# The Universal Dependencies page has information about the annotated corpora available for each language; it's worth looking into the corpora that were annotated for your language.

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# Above is a POS chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different parts of speech that spaCy can identify as well as their corresponding labels. To quickly see spaCy's POS tagging in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) on our sample `document` with the `style=` parameter set to "dep" (short for dependency parsing):

# %% [markdown]
# ## Get Part-Of-Speech Tags

# %% [markdown]
# To get part of speech tags for every word in a document, we have to iterate through all the tokens in the document and pull out the `.lemma_` attribute for each token, which gives us the un-inflected version of the word. We'll also pull out the  `.pos_` attribute for each token. We can get even finer-grained dependency information with the attribute `.dep_`.

# %%
for token in document:
    print(token.lemma_, token.pos_, token.dep_)
# Out:
# яблони PROPN nsubj
# цвести VERB ROOT
# * PUNCT punct
#
#
#  SPACE conj
# i PROPN appos
#
#  SPACE punct
# зачем ADV advmod
# она PRON nsubj
# так ADV advmod
# сделать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# не PART advmod
# уметь VERB ccomp
# жить VERB xcomp
# без ADP case
# нее PRON obl
# ? PUNCT punct
# это PRON obj
# она PRON nsubj
# сделать VERB ROOT
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# виноватый ADJ conj
# … PUNCT punct
#
#
#  SPACE parataxis
# я PRON nsubj
# написать VERB ROOT
# это PRON obj
# – PUNCT punct
# и CCONJ cc
# мне PRON iobj
# стать VERB parataxis
# странный ADJ xcomp
# . PUNCT punct
# говорить VERB ROOT
# точно ADV advmod
# о ADP case
# возлюбленной NOUN obl
# . PUNCT punct
# но CCONJ cc
# возлюбленной NOUN nsubj
# у ADP case
# меня PRON obl
# нет VERB ROOT
# . PUNCT punct
# это PRON obj
# мой DET det
# мать NOUN nsubj
# сделать VERB ROOT
# так ADV advmod
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# умирать VERB advcl
# без ADP case
# нее PRON obl
# . PUNCT punct
# если SCONJ mark
# человек NOUN obj
# держать VERB advcl
# в ADP case
# тепло NOUN obl
# весь DET det
# жизнь NOUN obj
# , PUNCT punct
# а CCONJ cc
# потом ADV advmod
# неодетый ADJ obj
# выгнать VERB conj
# на ADP case
# двадцатиградусный ADJ amod
# мороз NOUN obl
# , PUNCT punct
# он PRON nsubj
# непременно ADV advmod
# умереть VERB ROOT
# . PUNCT punct
# и CCONJ cc
# я PRON nsubj
# умереть VERB ROOT
# . PUNCT punct
# умру NOUN ROOT
# из ADP case
# - ADP case
# за ADP case
# нее PRON nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# давно ADV advmod
# уж PART advmod
# мне PRON iobj
# хотеться VERB conj
# рассказать VERB xcomp
# кто PRON iobj
# - PRON iobj
# нибудь PRON iobj
# все PRON obj
# , PUNCT punct
# о ADP case
# что PRON obl
# я PRON nsubj
# думать VERB acl:relcl
# , PUNCT punct
# или CCONJ cc
# хоть ADV advmod
# написать VERB conj
# . PUNCT punct
# рассказать VERB xcomp
# некому VERB xcomp
# , PUNCT punct
# никто PRON nsubj
# не PART advmod
# хотеть VERB ROOT
# , PUNCT punct
# чтобы SCONJ mark
# я PRON nsubj
# рассказывать VERB ccomp
# , PUNCT punct
# так ADV advmod
# уж PART advmod
# хороший ADJ advmod
# я PRON nsubj
# написать VERB ccomp
# . PUNCT punct
# все PART advmod
# - PART advmod
# таки PART advmod
# лёгкий ADJ ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# мне PRON iobj
# казаться VERB ccomp
# , PUNCT punct
# что SCONJ mark
# этот DET det
# последний ADJ amod
# день NOUN nsubj
# – PUNCT punct
# важный ADJ amod
# и CCONJ cc
# значительный ADJ conj
# день NOUN ccomp
# для ADP case
# меня PRON nmod
# . PUNCT punct
# я PRON nsubj
# до ADP case
# что PRON obl
# - PRON obj
# то PRON obl
# дойти VERB ROOT
# , PUNCT punct
# кончить VERB conj
# половина NOUN obj
# мой DET det
# жизнь NOUN nmod
# , PUNCT punct
# а CCONJ cc
# дальше ADV advmod
# дорога NOUN nsubj
# прямой ADJ amod
# , PUNCT punct
# унылый ADJ conj
# , PUNCT punct
# быстрый ADJ conj
# и CCONJ cc
# такой DET det
# однообразный ADJ conj
# , PUNCT punct
# что PRON nsubj
# уже ADV advmod
# нельзя ADV ccomp
# будет AUX cop
# заметить VERB csubj
# , PUNCT punct
# идти VERB ccomp
# ли PART advmod
# вперед ADV advmod
# или CCONJ cc
# назад ADV conj
# , PUNCT punct
# вверх ADV conj
# или CCONJ cc
# вниз ADV conj
# . PUNCT punct
# и CCONJ cc
# не PART advmod
# знать VERB ROOT
# , PUNCT punct
# нужный ADJ ccomp
# ли PART advmod
# покориться VERB csubj
# , PUNCT punct
# как SCONJ mark
# всегда ADV advmod
# , PUNCT punct
# и CCONJ cc
# идти VERB conj
# по ADP case
# ней PRON obl
# . PUNCT punct
#
#
#  SPACE ROOT
# мне PRON iobj
# теперь ADV advmod
# двадцать NUM nummod:gov
# восемь NUM nummod:gov
# год NOUN obl
# , PUNCT punct
# но CCONJ cc
# никто PRON nsubj
# это PRON iobj
# не PART advmod
# верить VERB conj
# , PUNCT punct
# такой DET det
# старый ADJ obl
# я PRON nsubj
# кадиться VERB conj
# . PUNCT punct
# я PRON nsubj
# сам ADJ acl
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# старик NOUN ccomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# быть VERB ROOT
# прежде ADV advmod
# красивый ADJ amod
# и CCONJ cc
# нежный ADJ conj
# лицо NOUN nsubj
# , PUNCT punct
# как SCONJ case
# у ADP case
# мама NOUN acl
# , PUNCT punct
# мы PRON nsubj
# с ADP case
# ней PRON obl
# часто ADV advmod
# вместе ADV advmod
# смотрелись VERB conj
# в ADP case
# зеркало NOUN obl
# , PUNCT punct
# и CCONJ cc
# нам PRON iobj
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# мы PRON nsubj
# удивительно ADV advmod
# похожий ADJ ccomp
# друг PRON obl
# на ADP fixed
# друга PRON fixed
# . PUNCT punct
#
#
#  SPACE ROOT
# теперь ADV advmod
# она PRON nsubj
# не PART advmod
# узнать VERB ccomp
# бы AUX aux
# меня PRON obj
# . PUNCT punct
# я PRON nsubj
# согнуться VERB ROOT
# , PUNCT punct
# глаз NOUN nsubj
# потускнуть VERB conj
# , PUNCT punct
# борода NOUN nsubj
# вырасти VERB conj
# больший ADJ nsubj
# , PUNCT punct
# лицо NOUN nsubj
# стать VERB conj
# жёлтый ADJ xcomp
# , PUNCT punct
# тёмный ADJ conj
# . PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# скоро ADV advmod
# умереть VERB ccomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# нет VERB ROOT
# , PUNCT punct
# казаться VERB parataxis
# , PUNCT punct
# никакой DET det
# болезнь NOUN nsubj
# , PUNCT punct
# но CCONJ cc
# я PRON nsubj
# должный ADJ conj
# умереть VERB xcomp
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# жить VERB advcl
# тот DET nsubj
# , PUNCT punct
# кто PRON nsubj
# хотеть VERB acl:relcl
# , PUNCT punct
# кто PRON nsubj
# иметь VERB ccomp
# воля NOUN obj
# жить VERB xcomp
# , PUNCT punct
# а CCONJ cc
# у ADP case
# меня PRON obl
# нет VERB conj
# воля NOUN nsubj
# . PUNCT punct
# в ADP case
# последний ADJ amod
# день NOUN ROOT
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# это PRON obj
# сознал VERB acl:relcl
# и CCONJ cc
# увидеть VERB conj
# , PUNCT punct
# что SCONJ mark
# мне PRON iobj
# больше ADV advmod
# и CCONJ cc
# ждать VERB csubj
# нечего VERB ccomp
# – PUNCT punct
# я PRON nsubj
# даже PART advmod
# думать VERB parataxis
# о ADP case
# самоубийство NOUN obl
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# не PART advmod
# мочь VERB ROOT
# . PUNCT punct
# я PRON nsubj
# бояться VERB ROOT
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# меня PRON ccomp
# пошлый ADJ amod
# и CCONJ cc
# трусливый ADJ conj
# сердце NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# бояться VERB ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# весь DET det
# это PRON obj
# она PRON nsubj
# сделать VERB ccomp
# . PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# – PUNCT punct
# что SCONJ mark
# от ADP case
# нее PRON nmod
# же PART advmod
# у ADP case
# меня PRON ccomp
# тот DET det
# чувство NOUN nsubj
# , PUNCT punct
# которое PRON nsubj
# совсем ADV advmod
# не PART advmod
# пойти VERB acl:relcl
# , PUNCT punct
# и CCONJ cc
# одно NUM nsubj
# давать VERB conj
# мне PRON iobj
# счастие NOUN obj
# жизнь NOUN nmod
# – PUNCT punct
# сентиментальность NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# стыжусь VERB ROOT
# этот DET det
# слово NOUN obj
# , PUNCT punct
# как SCONJ mark
# все PRON nsubj
# стыдиться VERB acl
# . PUNCT punct
# да PART parataxis
# , PUNCT punct
# все PRON nsubj
# стыдиться VERB ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# у ADP case
# всех PRON obl
# оно PRON nsubj
# быть VERB advcl
# … PUNCT punct
#
#
#  SPACE parataxis
# я PRON nsubj
# музыкант NOUN ROOT
# и CCONJ ROOT
# если SCONJ mark
# не PART advmod
# хороший ADJ discourse
# , PUNCT punct
# то SCONJ mark
# порядочный ADJ discourse
# , PUNCT punct
# как SCONJ mark
# говорить VERB discourse
# . PUNCT punct
# думать VERB parataxis
# , PUNCT punct
# хороший ADJ xcomp
# я PRON nsubj
# и PART cc
# не PART advmod
# мочь VERB ROOT
# быть VERB xcomp
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# , PUNCT punct
# когда SCONJ mark
# играть VERB advcl
# длинный ADJ amod
# , PUNCT punct
# трудный ADJ conj
# рапсодия NOUN obj
# и CCONJ cc
# фуга NOUN conj
# , PUNCT punct
# даже PART advmod
# сонаты NOUN conj
# , PUNCT punct
# я PRON nsubj
# совершенно ADV advmod
# холодный ADJ advcl
# , PUNCT punct
# и CCONJ cc
# мысль NOUN discourse
# у ADP case
# меня PRON conj
# самые ADJ amod
# обыденный ADJ nsubj
# , PUNCT punct
# скучный ADJ conj
# . PUNCT punct
# чувство NOUN nsubj
# прекрасный ADJ nmod
# редко ADV advmod
# бывать VERB ROOT
# у ADP case
# меня PRON obl
# ; PUNCT punct
# это PRON nsubj
# – PUNCT punct
# совсем ADV advmod
# не PART advmod
# сентиментальный ADJ amod
# чувство NOUN conj
# , PUNCT punct
# оно PRON nsubj
# захватывать VERB conj
# и CCONJ cc
# звать VERB conj
# вперед ADV advmod
# , PUNCT punct
# а CCONJ cc
# мне PRON iobj
# это PRON nsubj
# трудный ADJ conj
# ; PUNCT punct
# я PRON nsubj
# любить VERB conj
# тихий ADJ amod
# умиление NOUN obj
# , PUNCT punct
# воспоминание NOUN conj
# , PUNCT punct
# когда SCONJ mark
# так ADV advmod
# сладко ADV advmod
# болеть VERB acl
# сердце NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# в ADP case
# душа NOUN conj
# глубокий ADJ amod
# тишина NOUN nsubj
# . PUNCT punct
#
#
#  SPACE ROOT
# бывать VERB obj
# , PUNCT punct
# играть VERB advcl
# блестеть VERB amod
# прелюдия NOUN obj
# в ADP case
# концерт NOUN nmod
# ( PUNCT punct
# теперь ADV advmod
# уж PART advmod
# давно ADV advmod
# я PRON nsubj
# не PART advmod
# выходить VERB parataxis
# на ADP case
# эстрада NOUN obl
# ) PUNCT punct
# , PUNCT punct
# я PRON nsubj
# взглядывать VERB parataxis
# на ADP case
# какой DET det
# - DET det
# нибудь DET det
# пожилой ADJ amod
# господин NOUN obl
# в ADP case
# первый ADJ amod
# ряд NOUN obl
# и CCONJ cc
# думать VERB conj
# : PUNCT punct
# " PUNCT punct
# вот PART advmod
# ты PRON nsubj
# смотреть VERB parataxis
# на ADP case
# меня PRON obl
# , PUNCT punct
# слушать VERB conj
# внимательно ADV advmod
# и CCONJ cc
# знать VERB conj
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# играть VERB ccomp
# , PUNCT punct
# потом ADV advmod
# будешь AUX aux
# делать VERB conj
# толковый ADJ amod
# замечание NOUN obj
# о ADP case
# мой DET det
# „ PUNCT punct
# техника NOUN nmod
# “ PUNCT punct
# и CCONJ cc
# „ PUNCT punct
# экспрессия NOUN conj
# … PUNCT punct
# “ PUNCT punct
# а CCONJ cc
# если SCONJ mark
# бы AUX aux
# я PRON nsubj
# бросить VERB advcl
# теперь ADV advmod
# этот DET det
# прелюдия NOUN obj
# и CCONJ cc
# сыграть VERB conj
# маленький ADJ amod
# , PUNCT punct
# простой ADJ conj
# малороссийский ADJ amod
# песенка NOUN obj
# , PUNCT punct
# которая PRON nsubj
# напомнить VERB acl:relcl
# бы AUX aux
# тебе PRON iobj
# далёкий ADJ amod
# год NOUN obj
# , PUNCT punct
# тёмный ADJ amod
# , PUNCT punct
# тёплый ADJ conj
# сад NOUN conj
# и CCONJ cc
# , PUNCT punct
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# чей DET det
# - DET det
# нибудь DET det
# милый ADJ amod
# , PUNCT punct
# забыть VERB conj
# глаз NOUN conj
# – PUNCT punct
# ты PRON nsubj
# встать VERB ROOT
# бы AUX aux
# и CCONJ cc
# уйти VERB conj
# , PUNCT punct
# чтобы SCONJ mark
# скрыть VERB advcl
# невольный ADJ amod
# слеза NOUN obj
# , PUNCT punct
# радостный ADJ amod
# грусть NOUN conj
# и CCONJ cc
# счастие NOUN conj
# , PUNCT punct
# которого PRON obj
# не PART advmod
# давать VERB acl:relcl
# тебе PRON iobj
# блестеть VERB amod
# прелюдия NOUN nsubj
# . PUNCT punct
# и CCONJ cc
# непременно ADV advmod
# ты PRON nsubj
# хотеть VERB ROOT
# бы AUX aux
# скрыть VERB xcomp
# этот DET det
# счастие NOUN obj
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# тебе PRON iobj
# стыдно ADV advcl
# и CCONJ cc
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# ты PRON nsubj
# один DET amod
# так ADV advmod
# чувствовать VERB ccomp
# и CCONJ advmod
# другие ADJ nsubj
# не PART advmod
# понять VERB conj
# , PUNCT punct
# а CCONJ cc
# между ADP case
# тем PRON obl
# все PART advmod
# так ADV advmod
# же PART advmod
# чувствовать VERB conj
# – PUNCT punct
# и CCONJ cc
# каждый DET nsubj
# стыдиться VERB parataxis
# , PUNCT punct
# думать VERB advcl
# , PUNCT punct
# что SCONJ mark
# он PRON nsubj
# один DET ccomp
# . PUNCT punct
# у ADP case
# каждый DET obl
# быть VERB ROOT
# светлый ADJ amod
# облако NOUN nsubj
# в ADP case
# прошлое NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# и CCONJ cc
# у ADP case
# меня PRON obl
# оно PRON nsubj
# быть VERB conj
# , PUNCT punct
# как SCONJ case
# у ADP case
# всех PRON obl
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE ROOT
# ii ADJ appos
#
#  SPACE punct
# скучный ADJ ROOT
# рассказывать VERB csubj
# с ADP case
# самого ADJ amod
# начало NOUN obl
# , PUNCT punct
# с ADV advmod
# тот DET fixed
# пора NOUN fixed
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# был AUX cop
# ребёнок NOUN conj
# . PUNCT punct
# да CCONJ cc
# и CCONJ fixed
# в ADP case
# двадцать NUM nummod:gov
# год NOUN obl
# я PRON nsubj
# жить VERB ROOT
# так ADV advmod
# же PART advmod
# , PUNCT punct
# как SCONJ case
# в ADP case
# десять NUM advcl
# . PUNCT punct
# только PART advmod
# в ADP case
# двадцать NUM nummod:gov
# я PRON nsubj
# был AUX cop
# счастливый ADJ ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# перерасти VERB advcl
# мама NOUN obj
# и CCONJ cc
# мочь VERB conj
# гулять VERB xcomp
# с ADP case
# ней PRON obl
# под ADP case
# рука NOUN obl
# . PUNCT punct
# отношение NOUN nsubj
# же PART advmod
# наш DET nsubj
# не PART advmod
# изменяться VERB ROOT
# . PUNCT punct
# бывать VERB ROOT
# , PUNCT punct
# мальчик NOUN obl
# я PRON nsubj
# часто ADV advmod
# делать VERB ccomp
# ей PRON iobj
# сцена NOUN obj
# , PUNCT punct
# когда SCONJ mark
# она PRON nsubj
# уезжать VERB advcl
# в ADP case
# театр NOUN obl
# без ADP case
# меня PRON obl
# , PUNCT punct
# говорить VERB conj
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# иметь VERB ccomp
# право NOUN obj
# веселиться VERB nmod
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# должный ADJ advcl
# учить VERB xcomp
# урок NOUN obj
# . PUNCT punct
# она PRON nsubj
# серьезно ADV advmod
# умоляла VERB ROOT
# простить VERB xcomp
# ее PRON obj
# , PUNCT punct
# даже PART advmod
# делаться VERB conj
# печальный ADJ xcomp
# , PUNCT punct
# если SCONJ mark
# я PRON nsubj
# дулся VERB advcl
# . PUNCT punct
# нам PRON iobj
# нельзя ADV ROOT
# было AUX cop
# ссориться VERB csubj
# . PUNCT punct
# у ADP case
# нее PRON obl
# не PART advmod
# быть VERB ROOT
# никто PRON nsubj
# , PUNCT punct
# кроме ADP case
# меня PRON nmod
# . PUNCT punct
# и CCONJ cc
# у ADP case
# меня PRON obl
# быть VERB cop
# она PRON nsubj
# один DET ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# с ADP case
# отец NOUN obl
# я PRON nsubj
# даже PART advmod
# не PART advmod
# разговаривать VERB conj
# никогда ADV advmod
# . PUNCT punct
# пожилой ADJ amod
# господин NOUN nsubj
# , PUNCT punct
# вечно ADV advmod
# занять VERB acl
# какой DET det
# - DET det
# то DET det
# постройка NOUN obl
# , PUNCT punct
# жить VERB acl
# в ADP case
# другой ADJ amod
# половина NOUN obl
# дом NOUN nmod
# , PUNCT punct
# он PRON nsubj
# совсем ADV advmod
# не PART advmod
# интересовать VERB ROOT
# меня PRON obj
# . PUNCT punct
# а CCONJ cc
# мама NOUN nsubj
# была AUX cop
# такой DET det
# молодой ADJ ROOT
# , PUNCT punct
# тоненький ADJ conj
# , PUNCT punct
# как SCONJ case
# девочка NOUN obl
# , PUNCT punct
# с ADP case
# больший ADJ amod
# чёрный ADJ amod
# глаз NOUN conj
# , PUNCT punct
# свежий ADJ conj
# , PUNCT punct
# блестящий ADJ conj
# ; PUNCT punct
# платье NOUN nsubj
# ее PRON det
# шуметь VERB conj
# при ADP case
# быстрый ADJ amod
# движение NOUN obl
# , PUNCT punct
# и CCONJ cc
# веять VERB conj
# от ADP case
# нее PRON obl
# какой DET det
# - DET det
# то DET det
# странный ADJ amod
# духами NOUN obl
# , PUNCT punct
# – PUNCT punct
# я PRON nsubj
# так ADV advmod
# и PART fixed
# не PART advmod
# узнать VERB parataxis
# , PUNCT punct
# как ADV advmod
# они PRON nsubj
# называться VERB ccomp
# . PUNCT punct
# запах NOUN nsubj
# их PRON det
# напоминать VERB ROOT
# самую ADJ amod
# ранний ADJ amod
# весна NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# конечно ADV parataxis
# , PUNCT punct
# мы PRON nsubj
# жить VERB parataxis
# в ADP case
# петербург PROPN obl
# . PUNCT punct
# я PRON nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# всех PRON obl
# быть VERB ccomp
# что PRON nsubj
# - PRON nsubj
# то PRON nsubj
# необычный ADJ amod
# , PUNCT punct
# светлый ADJ amod
# в ADP case
# прошлое NOUN obl
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# не PART advmod
# знать VERB ROOT
# и CCONJ cc
# сомневаться VERB conj
# , PUNCT punct
# что SCONJ mark
# мочь VERB ccomp
# быть AUX cop
# у ADP case
# человек NOUN obl
# , PUNCT punct
# которые PRON nsubj
# родиться VERB acl:relcl
# в ADP case
# петербург PROPN obl
# и CCONJ cc
# не PART advmod
# видали VERB conj
# другого ADJ amod
# солнце NOUN obj
# . PUNCT punct
# хороший ADJ ROOT
# , PUNCT punct
# если SCONJ mark
# я PRON nsubj
# ошибаться VERB advcl
# и PART advmod
# сужу NOUN iobj
# по ADP case
# себя PRON nmod
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# никогда ADV advmod
# не PART advmod
# примирюсь VERB ROOT
# с ADP case
# этот DET det
# низкий ADJ amod
# небо NOUN obl
# и CCONJ cc
# тёмный ADJ amod
# воздух NOUN conj
# , PUNCT punct
# с ADP case
# этот DET det
# квартира NOUN conj
# , PUNCT punct
# где ADV advmod
# я PRON nsubj
# один DET acl:relcl
# . PUNCT punct
# впрочем ADV parataxis
# , PUNCT punct
# об ADP case
# это PRON obl
# впереди ADV ROOT
# . PUNCT punct
# и CCONJ cc
# все PRON parataxis
# равный ADJ fixed
# , PUNCT punct
# я PRON nsubj
# один DET nummod
# в ADP case
# целое NOUN nmod
# свет NOUN ROOT
# , PUNCT punct
# как ADV advmod
# же PART advmod
# мне PRON iobj
# не PART advmod
# быть AUX cop
# одному NUM nummod
# в ADP case
# этот DET det
# квартира NOUN nmod
# ? PUNCT punct
#
#
#  SPACE ROOT
# мы PRON nsubj
# жить VERB ROOT
# в ADP case
# большой ADJ amod
# город NOUN obl
# на ADP case
# юг NOUN nmod
# , PUNCT punct
# в ADP case
# свой DET det
# дом NOUN conj
# . PUNCT punct
# дом NOUN nsubj
# был AUX cop
# новый ADJ ROOT
# , PUNCT punct
# выстроить VERB conj
# отец NOUN obl:agent
# , PUNCT punct
# неудобный ADJ conj
# и CCONJ cc
# холодный ADJ conj
# . PUNCT punct
# во ADP case
# двор NOUN obl
# был AUX cop
# небольшой ADJ amod
# , PUNCT punct
# но CCONJ cc
# чистый ADJ conj
# сад NOUN ROOT
# , PUNCT punct
# к ADP case
# которому PRON obl
# со ADP case
# весь DET det
# сторона NOUN obl
# примыкать VERB acl:relcl
# чужой ADJ amod
# сад NOUN obj
# , PUNCT punct
# а CCONJ cc
# потому ADV advmod
# он PRON nsubj
# казаться VERB conj
# мне PRON iobj
# бесконечный ADJ xcomp
# . PUNCT punct
# отец NOUN nsubj
# все PRON det
# хотеть VERB ROOT
# его PRON obj
# вырубить VERB xcomp
# и CCONJ cc
# построить VERB conj
# два NUM nummod:gov
# флигель NOUN obj
# и CCONJ cc
# сарай NOUN conj
# , PUNCT punct
# но CCONJ cc
# так ADV advmod
# и PART fixed
# не PART advmod
# собраться VERB conj
# . PUNCT punct
# не PART advmod
# знать VERB ROOT
# , PUNCT punct
# впрочем ADV parataxis
# , PUNCT punct
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# теперь ADV advmod
# уж PART advmod
# и PART advmod
# нет VERB ccomp
# наш DET det
# сад NOUN nsubj
# . PUNCT punct
# не PART advmod
# знать VERB ROOT
# , PUNCT punct
# да CCONJ cc
# и CCONJ fixed
# знать VERB xcomp
# не PART advmod
# хотеть VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# никогда ADV advmod
# не PART advmod
# был AUX cop
# в ADP case
# гимназия NOUN ccomp
# . PUNCT punct
# в ADP case
# самом ADJ amod
# дело NOUN parataxis
# , PUNCT punct
# с ADP case
# кто PRON obl
# бы AUX aux
# мама NOUN nsubj
# оставаться VERB ROOT
# ? PUNCT punct
# у ADP case
# нее PRON obl
# быть VERB ROOT
# много ADV nsubj
# знакомых NOUN obl
# , PUNCT punct
# но CCONJ cc
# никто PRON nsubj
# никогда ADV advmod
# за ADP case
# ней PRON obl
# не PART advmod
# ухаживать VERB conj
# серьезно ADV advmod
# , PUNCT punct
# хотя SCONJ mark
# и PART advmod
# знать VERB advcl
# её DET det
# отношение NOUN obj
# к ADP case
# отец NOUN nmod
# . PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# она PRON nsubj
# сама ADJ acl
# не PART advmod
# хотеть VERB ccomp
# . PUNCT punct
#
#
#  SPACE ROOT
# у ADP case
# меня PRON obl
# быть VERB ccomp
# хороший ADJ amod
# гимназический ADJ amod
# учитель NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# учиться VERB conj
# недурно ADV advmod
# . PUNCT punct
# мама NOUN nsubj
# , PUNCT punct
# конечно ADV parataxis
# , PUNCT punct
# учиться VERB ROOT
# со ADP case
# мною PRON obl
# , PUNCT punct
# но CCONJ cc
# ей PRON iobj
# часто ADV advmod
# надоедать VERB conj
# , PUNCT punct
# и CCONJ cc
# она PRON nsubj
# говорить VERB conj
# : PUNCT punct
#
#
#  SPACE parataxis
# – PUNCT punct
# володя PROPN parataxis
# , PUNCT punct
# бросим VERB conj
# книга NOUN obj
# , PUNCT punct
# пойти VERB conj
# гулять VERB xcomp
# , PUNCT punct
# а CCONJ conj
# ? PUNCT punct
#
#
#  SPACE conj
# и CCONJ cc
# мы PRON nsubj
# идти VERB ROOT
# , PUNCT punct
# – PUNCT punct
# она PRON nsubj
# нарядный ADJ parataxis
# , PUNCT punct
# весёлый ADJ conj
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# счастливый ADJ conj
# , PUNCT punct
# что SCONJ mark
# у ADP case
# меня PRON ccomp
# такой DET det
# хорошенький ADJ amod
# мама NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# так ADV advmod
# на ADP case
# нее PRON obl
# похожий ADJ conj
# . PUNCT punct
#
#
#  SPACE ROOT
# она PRON nsubj
# совсем ADV advmod
# не PART advmod
# изменяться VERB conj
# , PUNCT punct
# не PART advmod
# стареть VERB conj
# , PUNCT punct
# и CCONJ cc
# скоро ADV advmod
# нас PRON obj
# стать VERB conj
# принимать VERB xcomp
# за ADP case
# брат NOUN obl
# и CCONJ cc
# сестра NOUN conj
# , PUNCT punct
# особенно ADV advmod
# когда SCONJ mark
# у ADP case
# меня PRON obl
# вырасти VERB advcl
# ус NOUN nsubj
# и CCONJ cc
# маленький ADJ amod
# борода NOUN conj
# . PUNCT punct
# мне PRON iobj
# казаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# и PART cc
# я PRON nsubj
# не PART advmod
# измениться VERB ccomp
# внутренне ADV advmod
# . PUNCT punct
# только PART advmod
# к ADP case
# двадцать NUM nummod
# год NOUN obl
# я PRON nsubj
# серьезно ADV advmod
# стать VERB ROOT
# заниматься VERB xcomp
# музыка NOUN obl
# и CCONJ cc
# мечтать VERB conj
# о ADP case
# консерватория NOUN obl
# . PUNCT punct
# гимназический ADJ amod
# экзамен NOUN obj
# я PRON nsubj
# сдать VERB ROOT
# хорошо ADV advmod
# , PUNCT punct
# и CCONJ cc
# надо ADV conj
# было AUX cop
# на ADP case
# что PRON obl
# - PRON obl
# нибудь PRON obl
# решаться VERB csubj
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# ты PRON nsubj
# поехать VERB parataxis
# в ADP case
# консерватория NOUN obl
# , PUNCT punct
# в ADP case
# москва PROPN conj
# , PUNCT punct
# непременно ADV advmod
# , PUNCT punct
# – PUNCT punct
# говорить VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
# – PUNCT punct
# надо ADV ROOT
# скорее ADV advmod
# , PUNCT punct
# тебе PRON iobj
# уже ADV advmod
# двадцать NUM nummod:gov
# год NOUN conj
# . PUNCT punct
# ты PRON nsubj
# будешь AUX cop
# знаменитый ADJ ROOT
# , PUNCT punct
# вот PART advmod
# увидеть VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# а CCONJ cc
# когда ADV advmod
# же PART advmod
# мы PRON nsubj
# поехать VERB parataxis
# ? PUNCT punct
#
#
#  SPACE conj
# – PUNCT punct
# осень NOUN parataxis
# , PUNCT punct
# я PRON nsubj
# думать VERB parataxis
# . PUNCT punct
# хороший ADJ ROOT
# ? PUNCT punct
#
#
#  SPACE ROOT
# не PART advmod
# быть VERB conj
# и PART advmod
# речь NOUN nsubj
# о ADP case
# том PRON nmod
# , PUNCT punct
# чтобы SCONJ mark
# мне PRON iobj
# ехать VERB acl
# без ADP case
# мама NOUN obl
# . PUNCT punct
# с ADP case
# кто PRON obl
# бы AUX aux
# я PRON nsubj
# стать VERB ROOT
# говорить VERB xcomp
# ? PUNCT punct
# кто PRON nsubj
# бы AUX aux
# ласкать VERB ROOT
# меня PRON obj
# и CCONJ cc
# ходить VERB conj
# со ADP case
# мною PRON obl
# гулять VERB xcomp
# ? PUNCT punct
# а CCONJ cc
# кто PRON nsubj
# бы AUX aux
# ухаживать VERB ROOT
# за ADP case
# мною PRON obl
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# заболею VERB advcl
# ? PUNCT punct
# да PART cc
# разве PART advmod
# возможный ADJ ROOT
# ей PRON iobj
# оставаться VERB csubj
# без ADP case
# меня PRON obl
# , PUNCT punct
# когда SCONJ mark
# мы PRON nsubj
# ни PART advmod
# на ADP case
# один NUM nummod
# день NOUN obl
# не PART advmod
# расставаться VERB advcl
# , PUNCT punct
# все PRON obj
# делать VERB conj
# и CCONJ cc
# обсуждать VERB conj
# сообща ADV advmod
# ? PUNCT punct
# я PRON nsubj
# и PART advmod
# заниматься VERB xcomp
# не PART advmod
# стать VERB ROOT
# бы AUX aux
# без ADP case
# нее PRON obl
# . PUNCT punct
#
#
#  SPACE ROOT
# так ADV advmod
# же PART advmod
# , PUNCT punct
# как SCONJ mark
# бывать VERB advcl
# ребёнок NOUN xcomp
# , PUNCT punct
# – PUNCT punct
# я PRON nsubj
# садиться VERB parataxis
# по ADP case
# вечер NOUN obl
# у ADP case
# огонь NOUN obl
# в ADP case
# её DET det
# комната NOUN nmod
# , PUNCT punct
# на ADP case
# пол NOUN conj
# , PUNCT punct
# около ADP case
# её DET det
# нога NOUN conj
# , PUNCT punct
# и CCONJ cc
# рассказывать VERB conj
# ей PRON iobj
# , PUNCT punct
# как SCONJ mark
# тот DET det
# и CCONJ cc
# тот DET det
# барышня NOUN nsubj
# в ADP case
# меня PRON obl
# влюблены ADJ ccomp
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# за ADP case
# ними PRON obl
# ухаживать VERB advcl
# , PUNCT punct
# и CCONJ cc
# какой DET det
# мне PRON iobj
# больше ADV advmod
# нравиться VERB conj
# . PUNCT punct
# мне PRON iobj
# в ADP case
# этот DET det
# время NOUN obl
# казаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# весь DET det
# барышня NOUN nsubj
# должный ADJ ccomp
# быть AUX aux:pass
# в ADP case
# меня PRON obl
# влюблены ADJ xcomp
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# я PRON nsubj
# такой DET det
# красивый ADJ advcl
# и CCONJ cc
# так ADV advmod
# хорошо ADV advmod
# играть VERB conj
# на ADP case
# фортепиано NOUN obl
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# знать VERB parataxis
# , PUNCT punct
# володя VERB parataxis
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# мне PRON iobj
# раз NOUN obl
# мама NOUN nsubj
# , PUNCT punct
# – PUNCT punct
# ведь SCONJ mark
# ты PRON nsubj
# совсем ADV advmod
# не PART advmod
# похожий ADJ parataxis
# на ADP case
# мужчина NOUN obl
# , PUNCT punct
# ты PRON nsubj
# совершенно ADV advmod
# женщина NOUN conj
# , PUNCT punct
# оттого ADV parataxis
# , PUNCT punct
# должный ADJ parataxis
# быть VERB xcomp
# , PUNCT punct
# мы PRON nsubj
# с ADP case
# тобой PRON obl
# так ADV advmod
# и PART fixed
# сойтись VERB conj
# … PUNCT punct
# или CCONJ cc
# это PRON obj
# я PRON nsubj
# сама ADJ acl
# так ADV advmod
# сделать VERB ROOT
# , PUNCT punct
# – PUNCT punct
# прибавить VERB parataxis
# она PRON nsubj
# подумать VERB obj
# . PUNCT punct
# – PUNCT punct
# ты PRON nsubj
# , PUNCT punct
# например ADV parataxis
# , PUNCT punct
# в ADP case
# мужской ADJ amod
# общество NOUN obl
# и CCONJ cc
# не PART advmod
# бывать VERB ROOT
# никогда ADV advmod
# ; PUNCT punct
# а CCONJ cc
# среди ADP case
# женщина NOUN obl
# я PRON nsubj
# тебя PRON obj
# видеть VERB conj
# – PUNCT punct
# там ADV advmod
# ты PRON nsubj
# тоже ADV advmod
# как ADV advmod
# - ADV advmod
# то ADV advmod
# не PART advmod
# ухаживать VERB parataxis
# , PUNCT punct
# а CCONJ cc
# кокетничать VERB conj
# . PUNCT punct
# не PART advmod
# знать VERB ROOT
# … PUNCT punct
# но CCONJ cc
# мне PRON iobj
# казаться VERB conj
# , PUNCT punct
# будь AUX cop
# ты PRON nsubj
# мне PRON iobj
# чужой ADJ ccomp
# – PUNCT punct
# ты PRON nsubj
# мне PRON iobj
# не PART advmod
# понравиться VERB parataxis
# бы AUX aux
# . PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# страшно ADV advmod
# обидеться VERB ccomp
# и CCONJ cc
# надуться VERB conj
# . PUNCT punct
# как SCONJ ROOT
# ! PUNCT punct
# сама ADJ amod
# же PART advmod
# она PRON nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# похожий ADJ ccomp
# на ADP case
# нее PRON obl
# , PUNCT punct
# а CCONJ cc
# теперь ADV advmod
# я PRON nsubj
# ей PRON iobj
# не PART advmod
# нравиться VERB conj
# ! PUNCT punct
# если SCONJ mark
# это PRON nsubj
# и PART advmod
# не PART advmod
# хороший ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# похожий ADJ ccomp
# на ADP case
# женщина NOUN obl
# , PUNCT punct
# то SCONJ mark
# ведь PART mark
# она PRON nsubj
# же PART advmod
# сама ADJ acl
# прежде ADV advmod
# это PRON obl
# не PART advmod
# бояться VERB advcl
# ? PUNCT punct
#
#
#  SPACE ROOT
# да PART cc
# и CCONJ cc
# что SCONJ mark
# тут ADV advmod
# нехороший ADJ conj
# ? PUNCT punct
# пусть PART advmod
# я PRON nsubj
# похожий ADJ ROOT
# на ADP case
# женщина NOUN obl
# ! PUNCT punct
# я PRON nsubj
# любить VERB ROOT
# прежде ADV advmod
# всего PRON fixed
# весь DET det
# красивый ADJ obj
# – PUNCT punct
# но CCONJ cc
# без ADP case
# суровость NOUN conj
# , PUNCT punct
# без ADP case
# сила NOUN conj
# , PUNCT punct
# а CCONJ cc
# нежный ADJ conj
# и CCONJ cc
# простой ADJ conj
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# виноватый ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# такой DET det
# … PUNCT punct
#
#
#  SPACE ccomp
# мама NOUN nsubj
# долго ADV advmod
# просить VERB ROOT
# у ADP case
# меня PRON obl
# прощение NOUN obj
# , PUNCT punct
# и CCONJ cc
# мы PRON nsubj
# помириться VERB conj
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# не PART advmod
# забыть VERB ROOT
# её DET det
# слово NOUN obj
# и CCONJ cc
# часто ADV advmod
# потом ADV advmod
# говорить VERB conj
# ей PRON iobj
# : PUNCT punct
#
#
#  SPACE parataxis
# – PUNCT punct
# вот PART advmod
# сыромятников PROPN parataxis
# , PUNCT punct
# или CCONJ cc
# маремьянов PROPN conj
# , PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# какой DET det
# мужественный ADJ conj
# ? PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# они PRON nsubj
# должный ADJ ROOT
# нравиться VERB xcomp
# женщина NOUN iobj
# ? PUNCT punct
#
#
#  SPACE ROOT
# мама NOUN nsubj
# улыбаться VERB conj
# и CCONJ cc
# зажимала VERB conj
# мне PRON iobj
# рот NOUN obj
# свой DET det
# большой ADJ amod
# , PUNCT punct
# но CCONJ cc
# красивый ADJ conj
# рука NOUN obl
# с ADP case
# бесчисленный ADJ amod
# звенящий ADJ amod
# браслет NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# знать VERB ccomp
# , PUNCT punct
# что SCONJ mark
# делаться VERB ccomp
# фат NOUN obl
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# я PRON nsubj
# все PART advmod
# - PART advmod
# таки PART advmod
# очень ADV advmod
# нравиться VERB advcl
# тамошний ADJ amod
# барышня NOUN iobj
# , PUNCT punct
# знать VERB conj
# – PUNCT punct
# жизнь NOUN nsubj
# проходить VERB parataxis
# пусто ADV advmod
# , PUNCT punct
# и CCONJ cc
# сердце NOUN nsubj:pass
# делаться VERB conj
# пошлый ADJ iobj
# от ADP case
# этот DET det
# вечный ADJ amod
# рисовка NOUN nmod
# и CCONJ cc
# бесцельный ADJ amod
# желание NOUN conj
# нравиться VERB nmod
# . PUNCT punct
# сам ADJ amod
# я PRON nsubj
# ни PART advmod
# разу NOUN obl
# не PART advmod
# влюбляться VERB ROOT
# . PUNCT punct
# нравиться VERB ROOT
# многие NOUN nsubj
# , PUNCT punct
# но CCONJ cc
# не PART advmod
# сильно ADV conj
# . PUNCT punct
# в ADP case
# сущность NOUN obl
# , PUNCT punct
# я PRON nsubj
# был AUX cop
# очень ADV advmod
# чистый ADJ ROOT
# в ADP case
# тот DET det
# время NOUN nmod
# , PUNCT punct
# как SCONJ mark
# редкий ADJ acl
# , PUNCT punct
# но CCONJ cc
# мысленно ADV advmod
# я PRON nsubj
# оказываться VERB conj
# не PART advmod
# хороший ADJ advmod
# других ADJ obl
# . PUNCT punct
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# всегда ADV advmod
# чистый ADJ amod
# человек NOUN nsubj
# – PUNCT punct
# не PART advmod
# чистый ADJ ccomp
# в ADP case
# мысль NOUN obl
# ; PUNCT punct
# но CCONJ cc
# мне PRON iobj
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# это PRON nsubj
# неправда NOUN ccomp
# . PUNCT punct
# и CCONJ cc
# у ADP case
# меня PRON obl
# это PRON nsubj
# было AUX cop
# временно ADV ROOT
# и CCONJ cc
# , PUNCT punct
# я PRON nsubj
# думать VERB parataxis
# , PUNCT punct
# от ADP case
# робость NOUN conj
# , PUNCT punct
# от ADP case
# пошлый ADJ amod
# и CCONJ cc
# праздный ADJ conj
# жизнь NOUN conj
# , PUNCT punct
# и CCONJ cc
# оттого ADV conj
# , PUNCT punct
# что SCONJ mark
# меня PRON obj
# портить VERB ccomp
# и CCONJ cc
# баловать VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# iii ADJ appos
#
#  SPACE punct
# удивительный ADJ ROOT
# , PUNCT punct
# как ADV advmod
# мало ADV advmod
# меня PRON obj
# интересовать VERB ccomp
# книга NOUN nsubj
# . PUNCT punct
# я PRON nsubj
# их PRON obj
# читать VERB ROOT
# , PUNCT punct
# пока SCONJ mark
# не PART advmod
# сдать VERB advcl
# экзамен NOUN obj
# . PUNCT punct
# а CCONJ cc
# с ADV advmod
# тот DET fixed
# пора NOUN fixed
# я PRON nsubj
# заниматься VERB ROOT
# только PART advmod
# музыка NOUN obl
# . PUNCT punct
# она PRON nsubj
# один DET nummod
# меня PRON obj
# волновать VERB ROOT
# и CCONJ cc
# заставлять VERB conj
# вспоминать VERB xcomp
# то PRON obj
# , PUNCT punct
# что PRON nsubj
# не PART advmod
# быть VERB acl:relcl
# . PUNCT punct
# для ADP case
# музыка NOUN obl
# я PRON nsubj
# мочь VERB ROOT
# забыть VERB xcomp
# многое NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# наконец ADV advmod
# , PUNCT punct
# мы PRON nsubj
# поехать VERB parataxis
# в ADP case
# москва PROPN obl
# . PUNCT punct
# и CCONJ cc
# я PRON nsubj
# был AUX cop
# рад ADJ ROOT
# . PUNCT punct
# я PRON nsubj
# инстинктивно ADV advmod
# чувствовать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# надо ADV ccomp
# все PRON obj
# переменить VERB csubj
# . PUNCT punct
#
#
#  SPACE ROOT
# с ADP case
# нами PRON obl
# поехать VERB ccomp
# наш DET det
# старый ADJ amod
# экономка NOUN nsubj
# , PUNCT punct
# без ADP case
# нее PRON obl
# мы PRON nsubj
# совсем ADV advmod
# пропасть VERB conj
# бы AUX aux
# . PUNCT punct
# я PRON nsubj
# в ADP case
# москва PROPN obl
# никогда ADV advmod
# не PART advmod
# быть VERB ROOT
# , PUNCT punct
# а CCONJ cc
# мама NOUN nsubj
# хотя SCONJ mark
# и PART advmod
# жить VERB conj
# там ADV advmod
# прежде ADV advmod
# , PUNCT punct
# однако ADV advmod
# ничто PRON obj
# не PART advmod
# знать VERB conj
# и CCONJ cc
# не PART advmod
# уметь VERB conj
# . PUNCT punct
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# и CCONJ cc
# суметь VERB ROOT
# бы AUX aux
# , PUNCT punct
# но CCONJ cc
# ей PRON iobj
# было AUX cop
# скучный ADJ conj
# заботиться VERB csubj
# и CCONJ cc
# суетиться VERB conj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# это PRON obj
# отлично ADV advmod
# понимать VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# мы PRON nsubj
# нанять VERB ccomp
# хорошенький ADJ amod
# квартирка NOUN obj
# на ADP case
# малый ADJ amod
# никитский ADJ obl
# и CCONJ cc
# зажить VERB conj
# припеваючи NOUN obj
# , PUNCT punct
# по ADV parataxis
# - ADV advmod
# товарищески ADV advmod
# . PUNCT punct
# ездить VERB ROOT
# в ADP case
# театр NOUN obl
# , PUNCT punct
# кататься VERB conj
# . PUNCT punct
# скоро ADV advmod
# явиться VERB ROOT
# знакомые NOUN nsubj
# , PUNCT punct
# найтись VERB conj
# родственник NOUN nsubj
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# стать VERB ROOT
# заниматься VERB xcomp
# ревностно ADV advmod
# и CCONJ cc
# даже PART advmod
# редко ADV advmod
# выходить VERB conj
# , PUNCT punct
# когда SCONJ mark
# у ADP case
# мама NOUN obl
# быть VERB advcl
# гость NOUN nsubj
# . PUNCT punct
#
#
#  SPACE ROOT
# в ADP case
# консерватория NOUN obl
# я PRON nsubj
# ни PART advmod
# с ADP case
# кто PRON obl
# не PART advmod
# сошелся VERB conj
# , PUNCT punct
# кроме ADP case
# свой DET det
# профессор NOUN obl
# , PUNCT punct
# еще ADV advmod
# молодой ADJ amod
# человек NOUN conj
# . PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# ему PRON iobj
# казаться VERB conj
# странный ADJ xcomp
# , PUNCT punct
# хотя SCONJ mark
# , PUNCT punct
# как SCONJ mark
# он PRON nsubj
# говорить VERB parataxis
# , PUNCT punct
# очень ADV advmod
# талантливый ADJ advcl
# . PUNCT punct
# он PRON nsubj
# , PUNCT punct
# однако ADV parataxis
# , PUNCT punct
# угадать VERB ROOT
# меня PRON obj
# только PART advmod
# после ADP case
# того PRON obl
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# его PRON obj
# ввести VERB acl
# к ADP case
# нам PRON obl
# , PUNCT punct
# и CCONJ cc
# он PRON nsubj
# увидать VERB conj
# мой DET det
# мама NOUN obj
# . PUNCT punct
# нас PRON obj
# друг PRON nmod
# без ADP fixed
# друга PRON fixed
# понять VERB csubj
# было AUX cop
# нельзя ADV ROOT
# , PUNCT punct
# а CCONJ cc
# вместе ADV advmod
# , PUNCT punct
# как SCONJ mark
# говорить VERB parataxis
# , PUNCT punct
# мы PRON nsubj
# составлять VERB conj
# одно NUM nummod
# целое NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# смотреть VERB parataxis
# , PUNCT punct
# молодой ADJ amod
# человек NOUN parataxis
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# мне PRON iobj
# раз NOUN obj
# профессор NOUN nsubj
# , PUNCT punct
# – PUNCT punct
# заниматься VERB parataxis
# хорошенько ADV advmod
# . PUNCT punct
# из ADP case
# вас PRON obl
# должный ADJ ROOT
# выйти VERB xcomp
# что PRON obj
# - PRON obj
# нибудь PRON obj
# , PUNCT punct
# или CCONJ cc
# вы PRON nsubj
# совсем ADV advmod
# пропасть VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# и CCONJ cc
# я PRON nsubj
# заниматься VERB conj
# . PUNCT punct
# даже PART advmod
# лень NOUN nsubj
# свой DET obj
# забыть VERB ROOT
# , PUNCT punct
# не PART advmod
# заботиться VERB conj
# о ADP case
# волос NOUN obl
# и CCONJ cc
# об ADP case
# одежда NOUN conj
# , PUNCT punct
# редко ADV advmod
# выезжать VERB conj
# и CCONJ cc
# все PRON nsubj
# играть VERB conj
# свой DET det
# гамма NOUN obj
# . PUNCT punct
# я PRON nsubj
# их PRON obj
# не PART advmod
# любить VERB ROOT
# и CCONJ cc
# терпеть VERB conj
# только PART advmod
# , PUNCT punct
# как SCONJ case
# трудный ADJ amod
# лестница NOUN obl
# , PUNCT punct
# по ADP case
# которой PRON obl
# нужный ADJ acl:relcl
# взбираться VERB csubj
# наверх ADV advmod
# . PUNCT punct
# как SCONJ mark
# я PRON nsubj
# тосковать VERB ROOT
# о ADP case
# синий ADJ amod
# небо NOUN obl
# , PUNCT punct
# о ADP case
# земля NOUN conj
# , PUNCT punct
# о ADP case
# цвет NOUN conj
# ! PUNCT punct
# я PRON nsubj
# ни PART advmod
# о ADP case
# что PRON obl
# так ADV advmod
# не PART advmod
# тосковать VERB ROOT
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# думать VERB conj
# , PUNCT punct
# что SCONJ mark
# будет VERB ccomp
# тоска NOUN nsubj
# . PUNCT punct
# мама NOUN nsubj
# утешала VERB ROOT
# меня PRON obj
# , PUNCT punct
# но CCONJ cc
# … PUNCT punct
# это PRON nsubj
# было AUX cop
# мой DET det
# больной ADJ amod
# место NOUN conj
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# тут ADV advmod
# мы PRON nsubj
# не PART advmod
# понимать VERB ccomp
# друг PRON obj
# друга PRON fixed
# , PUNCT punct
# только PART advmod
# тут ADV advmod
# . PUNCT punct
# она PRON nsubj
# даже PART advmod
# сад NOUN nsubj
# наш DET obj
# не PART advmod
# любить VERB ROOT
# , PUNCT punct
# – PUNCT punct
# гулять VERB nsubj
# ходить VERB parataxis
# по ADP case
# улица NOUN obl
# , PUNCT punct
# говорить VERB conj
# , PUNCT punct
# что SCONJ mark
# солнечный ADJ amod
# свет NOUN nsubj
# гораздо ADV advmod
# беспокойный ADJ ccomp
# полутьма NOUN obl
# гостиная NOUN nmod
# , PUNCT punct
# а CCONJ cc
# её DET det
# дух NOUN nsubj
# хороший ADJ conj
# запах NOUN obl
# настоящий ADJ amod
# весна NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# когда SCONJ mark
# я PRON nsubj
# об ADP case
# это PRON obl
# думать VERB advcl
# , PUNCT punct
# приходило VERB conj
# невольный ADJ amod
# чувство NOUN nsubj
# на ADP case
# минута NOUN nmod
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# молодой ADJ acl
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# мочь VERB ccomp
# быть AUX cop
# вполне ADV advmod
# мой DET det
# товарищ NOUN xcomp
# , PUNCT punct
# что SCONJ mark
# в ADP case
# глубина NOUN obl
# душа NOUN nmod
# – PUNCT punct
# между ADP case
# нами PRON parataxis
# преграда NOUN nsubj
# . PUNCT punct
#
#
#  SPACE ROOT
# но CCONJ cc
# это PRON nsubj
# были AUX cop
# только PART advmod
# минута NOUN conj
# … PUNCT punct
#
#
#  SPACE punct
# я PRON nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# не PART advmod
# сойтись VERB ccomp
# ни PART advmod
# с ADP case
# кто PRON obl
# . PUNCT punct
# близко ADV advmod
# не PART advmod
# сходился VERB ROOT
# , PUNCT punct
# но CCONJ cc
# знакомиться VERB conj
# и CCONJ cc
# несколько NUM nummod:gov
# раз NOUN obl
# попадать VERB conj
# на ADP case
# кутёж NOUN obl
# , PUNCT punct
# не PART advmod
# ночевать VERB conj
# дома ADV advmod
# … PUNCT punct
#
#
#  SPACE conj
# мама NOUN nsubj
# расспрашивала VERB ROOT
# меня PRON obj
# с ADP case
# любопытство NOUN obl
# и CCONJ cc
# без ADP case
# всякий DET det
# упрёк NOUN conj
# , PUNCT punct
# но CCONJ cc
# я PRON nsubj
# был AUX cop
# как ADV advmod
# - ADV advmod
# то ADV advmod
# недовольный ADJ conj
# и CCONJ cc
# рассказывать VERB conj
# подробно ADV advmod
# с ADP case
# омерзение NOUN obl
# , PUNCT punct
# хотя SCONJ mark
# не PART advmod
# без ADP case
# гордость NOUN advcl
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# это PRON nsubj
# неважный ADJ parataxis
# , PUNCT punct
# володя VERB advcl
# , PUNCT punct
# – PUNCT punct
# говорить VERB parataxis
# мама NOUN nsubj
# . PUNCT punct
# – PUNCT punct
# это PART expl
# я PRON nsubj
# все PART advmod
# так ADV advmod
# и PART fixed
# думать VERB ROOT
# . PUNCT punct
# ты PRON nsubj
# только PART advmod
# меня PRON obj
# не PART advmod
# должный ADJ ROOT
# забывать VERB xcomp
# . PUNCT punct
# понимать VERB ROOT
# , PUNCT punct
# чтобы SCONJ mark
# я PRON nsubj
# была AUX cop
# у ADP case
# тебя PRON ccomp
# первый ADJ amod
# , PUNCT punct
# и CCONJ cc
# всегда ADV parataxis
# , PUNCT punct
# как SCONJ case
# ты PRON nsubj
# у ADP case
# меня PRON conj
# . PUNCT punct
# понимать VERB ROOT
# ? PUNCT punct
# иначе ADV advmod
# жить VERB csubj
# нельзя ADV ROOT
# . PUNCT punct
# понимать VERB ROOT
# ? PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# только PART advmod
# улыбаться VERB ROOT
# и CCONJ cc
# обнимал VERB conj
# ее PRON obj
# . PUNCT punct
# как ADV advmod
# же PART advmod
# она PRON nsubj
# мочь VERB ROOT
# быть AUX cop
# не PART advmod
# первый ADJ xcomp
# ? PUNCT punct
# кто PRON ROOT
# же PART advmod
# тогда ADV advmod
# ? PUNCT punct
#
#
#  SPACE ROOT
# iv ADJ appos
#
#  SPACE punct
# пройти VERB ROOT
# несколько NUM nummod:gov
# год NOUN obl
# . PUNCT punct
# я PRON nsubj
# кончать VERB ROOT
# консерватория NOUN obj
# , PUNCT punct
# выступать VERB conj
# в ADP case
# концерт NOUN obl
# – PUNCT punct
# и CCONJ cc
# с ADP case
# успех NOUN obl
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# сам ADJ acl
# был AUX cop
# не PART advmod
# совсем ADV advmod
# довольный ADJ ROOT
# . PUNCT punct
# что SCONJ nsubj
# мне PRON iobj
# в ADP case
# этот DET det
# трескучий ADJ amod
# пьесах NOUN ROOT
# , PUNCT punct
# где ADV advmod
# я PRON nsubj
# так ADV advmod
# быстро ADV advmod
# перебирать VERB acl:relcl
# палец NOUN iobj
# , PUNCT punct
# и CCONJ cc
# все PRON nsubj
# удивляться VERB conj
# и CCONJ cc
# хвалить VERB conj
# меня PRON obj
# ? PUNCT punct
# когда ADV advmod
# же PART advmod
# я PRON nsubj
# смочь VERB ROOT
# сыграть VERB xcomp
# то PRON obj
# , PUNCT punct
# что SCONJ obj
# слышать VERB acl
# часто ADV advmod
# – PUNCT punct
# но CCONJ cc
# что PRON nsubj
# ускользать VERB parataxis
# от ADP case
# меня PRON obl
# ? PUNCT punct
# если SCONJ mark
# суметь VERB advcl
# , PUNCT punct
# если SCONJ mark
# найду ADV advcl
# – PUNCT punct
# то SCONJ mark
# все PRON advmod
# сразу ADV advmod
# измениться VERB ROOT
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# буду AUX cop
# одно NUM nummod
# чувствовать VERB conj
# с ADP case
# тот DET det
# , PUNCT punct
# кто PRON nsubj
# слушать VERB acl:relcl
# . PUNCT punct
# мы PRON nsubj
# вместе ADV advmod
# будем AUX aux
# плакать VERB ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# оно PRON nsubj
# пройти VERB advcl
# не PART advmod
# мимо ADV advmod
# , PUNCT punct
# а CCONJ cc
# задеть VERB conj
# , PUNCT punct
# зацепить VERB conj
# самое ADJ amod
# тайный ADJ nsubj
# , PUNCT punct
# самое ADJ amod
# тайный ADJ conj
# , PUNCT punct
# самое ADJ amod
# глубокий ADJ conj
# , PUNCT punct
# одно NUM conj
# для ADP case
# всех PRON det
# … PUNCT punct
# да PART parataxis
# , PUNCT punct
# мы PRON nsubj
# будем AUX aux
# плакать VERB ROOT
# ; PUNCT punct
# потом ADV advmod
# … PUNCT punct
# потом ADV advmod
# все PRON nsubj
# равный ADJ fixed
# , PUNCT punct
# ну PART orphan
# – PUNCT punct
# умереть VERB conj
# . PUNCT punct
# все PRON ROOT
# равный ADJ fixed
# … PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# , PUNCT punct
# пока SCONJ mark
# я PRON nsubj
# сам ADJ acl
# не PART advmod
# чувствовать VERB advcl
# – PUNCT punct
# ничто PRON nsubj
# не PART advmod
# будет VERB ccomp
# ; PUNCT punct
# и CCONJ cc
# верить VERB conj
# без ADP case
# сомнение NOUN obl
# , PUNCT punct
# что SCONJ mark
# если SCONJ mark
# прийти VERB advcl
# ко ADP case
# мне PRON obl
# – PUNCT punct
# то SCONJ mark
# и PART advmod
# ко ADP case
# всем PRON obl
# прийти VERB ccomp
# , PUNCT punct
# кто PRON iobj
# я PRON nsubj
# буду AUX aux
# " PUNCT punct
# говорить VERB csubj
# " PUNCT punct
# . PUNCT punct
# я PRON nsubj
# всегда ADV advmod
# мысленно ADV advmod
# вместо ADP case
# " PUNCT punct
# играть VERB xcomp
# " PUNCT punct
# употреблять VERB ROOT
# выражение NOUN obj
# " PUNCT punct
# говорить VERB nmod
# с ADP case
# человек NOUN obl
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE csubj
# мочь VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# весь DET det
# это PRON nsubj
# было AUX cop
# не PART advmod
# умный ADJ ROOT
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# никогда ADV advmod
# не PART advmod
# считать VERB ROOT
# себя PRON obj
# умный ADJ amod
# человек NOUN xcomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# и CCONJ cc
# самолюбия NOUN nsubj
# тут ADV advmod
# не PART advmod
# быть VERB ROOT
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# не PART advmod
# развить VERB ccomp
# и CCONJ cc
# мало ADV advmod
# образовать VERB conj
# . PUNCT punct
# да CCONJ cc
# и PART fixed
# пусть PART ROOT
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# к ADP case
# это PRON obl
# идти VERB ROOT
# , PUNCT punct
# у ADP case
# меня PRON conj
# другое ADJ amod
# счастие NOUN nsubj
# , PUNCT punct
# другая ADJ amod
# дорога NOUN nsubj
# меня PRON obj
# повести VERB conj
# наверх ADV advmod
# . PUNCT punct
#
#
#  SPACE ROOT
# мама NOUN nsubj
# раз NOUN obl
# два NUM nummod:gov
# меня PRON nsubj
# оставлять VERB parataxis
# одного NUM obj
# на ADP case
# несколько NUM nummod:gov
# неделя NOUN obl
# , PUNCT punct
# ей PRON iobj
# необходимый ADJ conj
# было AUX cop
# уехать VERB csubj
# домой ADV advmod
# . PUNCT punct
# и CCONJ cc
# каждый DET det
# раз NOUN obl
# я PRON nsubj
# умирать VERB ROOT
# , PUNCT punct
# бросать VERB conj
# заниматься VERB xcomp
# , PUNCT punct
# почти ADV advmod
# не PART advmod
# есть VERB conj
# . PUNCT punct
# у ADP case
# меня PRON obl
# являться VERB ROOT
# какой DET det
# - DET det
# то DET det
# нервный ADJ amod
# ужас NOUN nsubj
# , PUNCT punct
# мне PRON iobj
# казаться VERB conj
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# один DET ccomp
# на ADP case
# свет NOUN obl
# , PUNCT punct
# ее PRON nsubj
# нет VERB conj
# и CCONJ cc
# не PART advmod
# быть VERB conj
# . PUNCT punct
# главный ADJ nsubj
# – PUNCT punct
# не PART advmod
# быть VERB ROOT
# ! PUNCT punct
# а CCONJ cc
# если SCONJ mark
# не PART advmod
# быть VERB ROOT
# , PUNCT punct
# – PUNCT punct
# значить VERB parataxis
# , PUNCT punct
# и CCONJ cc
# не PART advmod
# будет VERB conj
# … PUNCT punct
#
#
#  SPACE ROOT
# зачем ADV advmod
# она PRON nsubj
# так ADV advmod
# связать VERB conj
# меня PRON obj
# с ADP case
# собою NOUN obl
# , PUNCT punct
# что SCONJ mark
# жизнь NOUN nsubj
# без ADP case
# нее PRON obl
# не PART advmod
# мочь VERB ccomp
# длиться VERB xcomp
# ? PUNCT punct
# если SCONJ mark
# я PRON nsubj
# сказать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# любить VERB ccomp
# ее PRON obj
# – PUNCT punct
# это PRON nsubj
# будет AUX cop
# не PART advmod
# тот DET det
# слово NOUN parataxis
# : PUNCT punct
# не PART advmod
# любить VERB parataxis
# я PRON nsubj
# воздух NOUN obj
# , PUNCT punct
# пища NOUN conj
# , PUNCT punct
# – PUNCT punct
# а CCONJ cc
# жить VERB xcomp
# без ADP case
# них PRON obl
# не PART advmod
# мочь VERB conj
# . PUNCT punct
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# слабый ADJ amod
# , PUNCT punct
# слабый ADJ conj
# человек NOUN ccomp
# . PUNCT punct
# у ADP case
# меня PRON obl
# нет VERB ROOT
# сила NOUN nsubj
# сделать VERB nmod
# против ADP case
# себя PRON obl
# , PUNCT punct
# не PART advmod
# страдать VERB conj
# , PUNCT punct
# когда SCONJ mark
# я PRON nsubj
# страдать VERB advcl
# … PUNCT punct
#
#
#  SPACE conj
# я PRON nsubj
# был AUX cop
# последний ADJ amod
# год NOUN nsubj
# в ADP case
# москва PROPN obl
# , PUNCT punct
# когда SCONJ mark
# заболеть VERB advcl
# отец NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# мама NOUN nsubj
# уехать VERB conj
# перед ADP case
# рождество PROPN obl
# . PUNCT punct
# а CCONJ cc
# в ADP case
# конец NOUN obl
# январь NOUN nmod
# я PRON nsubj
# заболеть VERB ROOT
# сам ADJ acl
# , PUNCT punct
# бросить VERB conj
# все PRON obj
# и CCONJ cc
# приехать VERB conj
# домой ADV advmod
# . PUNCT punct
# что PRON nsubj
# ж PART advmod
# , PUNCT punct
# лишний ADJ amod
# год NOUN nsubj
# – PUNCT punct
# так ADV advmod
# лишний ADJ amod
# год NOUN ROOT
# , PUNCT punct
# а CCONJ cc
# заниматься VERB xcomp
# без ADP case
# нее PRON obl
# я PRON nsubj
# все ADV advmod
# равный ADJ fixed
# не PART advmod
# мочь VERB conj
# . PUNCT punct
# я PRON nsubj
# приехать VERB ROOT
# , PUNCT punct
# и CCONJ cc
# мы PRON nsubj
# целый ADJ amod
# вечер NOUN obl
# просидеть VERB conj
# вместе ADV advmod
# на ADP case
# диванчик NOUN obl
# в ADP case
# её DET det
# комната NOUN nmod
# и CCONJ cc
# молчать VERB conj
# … PUNCT punct
# но CCONJ cc
# я PRON nsubj
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# довольный ADJ ccomp
# . PUNCT punct
# она PRON nsubj
# так ADV advmod
# же PART advmod
# не PART advmod
# мочь VERB ROOT
# жить VERB xcomp
# без ADP case
# меня PRON obl
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# без ADP case
# нее PRON obl
# … PUNCT punct
#
#
#  SPACE conj
# v PROPN xcomp
#
#  SPACE punct
# я PRON nsubj
# проводить VERB ROOT
# день NOUN obj
# дом NOUN nmod
# и CCONJ cc
# много ADV advmod
# играть VERB conj
# . PUNCT punct
# у ADP case
# меня PRON obl
# быть VERB ROOT
# небольшой ADJ amod
# комната NOUN nsubj
# в ADP case
# одно NUM nummod
# окно NOUN nmod
# , PUNCT punct
# и CCONJ cc
# окно NOUN nsubj
# это PRON nsubj
# выходить VERB conj
# на ADP case
# двор NOUN obl
# , PUNCT punct
# к ADP case
# сад NOUN conj
# . PUNCT punct
# я PRON nsubj
# поставить VERB ROOT
# свой DET det
# рояль NOUN obj
# к ADP case
# окно NOUN obl
# и CCONJ cc
# смотреть VERB conj
# на ADP case
# небо NOUN obl
# и CCONJ cc
# на ADP case
# дерево NOUN conj
# , PUNCT punct
# когда SCONJ mark
# играть VERB advcl
# . PUNCT punct
#
#
#  SPACE nsubj
# в ADP case
# середина NOUN obl
# февраль NOUN nmod
# стать VERB ROOT
# совсем ADV advmod
# уж PART advmod
# тепло NOUN xcomp
# . PUNCT punct
# я PRON nsubj
# ходить VERB ROOT
# в ADP case
# сад NOUN obl
# и CCONJ cc
# смотреть VERB conj
# на ADP case
# голубой ADJ amod
# небо NOUN obl
# между ADP case
# голый ADJ amod
# ветвями NOUN nmod
# черешен NOUN nmod
# и CCONJ cc
# яблоня NOUN conj
# . PUNCT punct
# какой DET det
# оно PRON nsubj
# было AUX cop
# весёлый ADJ ROOT
# , PUNCT punct
# золотое VERB acl
# между ADP case
# чёрный ADJ amod
# сучьями NOUN obl
# ! PUNCT punct
# а CCONJ cc
# на ADP case
# дальний ADJ amod
# гора NOUN obl
# чуть ADV advmod
# желтеть VERB ROOT
# , PUNCT punct
# даже PART advmod
# еще ADV advmod
# не PART advmod
# зеленеть VERB conj
# , PUNCT punct
# а CCONJ cc
# желтеть VERB conj
# первый ADJ amod
# травка NOUN nsubj
# . PUNCT punct
# она PRON nsubj
# всегда ADV advmod
# из ADP case
# земля NOUN obl
# выходить VERB ROOT
# такой DET det
# светлый ADJ nsubj
# и CCONJ cc
# молодой ADJ conj
# , PUNCT punct
# что PRON nsubj
# казаться VERB parataxis
# жёлтый ADJ xcomp
# . PUNCT punct
# любить VERB ROOT
# я PRON nsubj
# этот DET det
# крошечный ADJ amod
# травинка NOUN obj
# , PUNCT punct
# первый ADJ amod
# ; PUNCT punct
# они PRON nsubj
# – PUNCT punct
# точно ADV advmod
# ребёнок NOUN conj
# , PUNCT punct
# любопытный ADJ amod
# и CCONJ cc
# неловкий ADJ conj
# , PUNCT punct
# подымать VERB conj
# серый ADJ amod
# комок NOUN obj
# земля NOUN nmod
# и CCONJ cc
# глядеть VERB conj
# на ADP case
# солнце NOUN obl
# . PUNCT punct
# ах INTJ parataxis
# , PUNCT punct
# мама NOUN ROOT
# … PUNCT punct
# зачем ADV advmod
# она PRON nsubj
# не PART advmod
# ходить VERB ROOT
# со ADP case
# мной PRON obl
# в ADP case
# сад NOUN obl
# и CCONJ cc
# не PART advmod
# любить VERB conj
# того PRON obj
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# любить VERB acl
# ? PUNCT punct
# и CCONJ cc
# опять ADV advmod
# холодный ADJ amod
# струя NOUN nsubj
# пробиралась VERB ROOT
# в ADP case
# мой DET det
# сердце NOUN obl
# , PUNCT punct
# опять ADV advmod
# отчуждённость NOUN conj
# … PUNCT punct
#
#
#  SPACE conj
# как ADV mark
# это PRON nsubj
# странный ADJ parataxis
# ! PUNCT punct
# и CCONJ cc
# как ADV advmod
# больно ADV ROOT
# … PUNCT punct
#
#
#  SPACE punct
# что PRON obl
# дальше ADV advmod
# идти VERB ROOT
# весна NOUN nsubj
# , PUNCT punct
# тем SCONJ mark
# больше ADV advmod
# я PRON nsubj
# сидеть VERB advcl
# в ADP case
# сад NOUN obl
# , PUNCT punct
# и CCONJ cc
# тем PRON obl
# радостнее ADV advmod
# мне PRON iobj
# становиться VERB conj
# . PUNCT punct
# точно ADV advmod
# я PRON nsubj
# сам ADJ acl
# ...
# и CCONJ cc
# серьезно ADV conj
# , PUNCT punct
# и CCONJ cc
# крепче ADV advmod
# прижималась VERB conj
# ко ADP case
# мне PRON obl
# . PUNCT punct
# я PRON nsubj
# хотеть VERB ROOT
# что PRON obj
# - PRON obj
# то PRON obj
# сказать VERB xcomp
# , PUNCT punct
# но CCONJ cc
# она PRON nsubj
# шепнуть VERB conj
# : PUNCT punct
# " PUNCT punct
# ни PART cc
# слово NOUN parataxis
# " PUNCT punct
# … PUNCT punct
# – PUNCT punct
# и CCONJ cc
# посмотреть VERB parataxis
# умоляюще ADV advmod
# . PUNCT punct
# я PRON nsubj
# замолчать VERB ROOT
# – PUNCT punct
# и CCONJ cc
# рад ADJ parataxis
# был AUX cop
# молчать VERB xcomp
# . PUNCT punct
# мне PRON iobj
# больше ADV advmod
# ничто PRON obj
# не PART advmod
# хотеться VERB ROOT
# , PUNCT punct
# кроме ADP case
# того PRON obl
# , PUNCT punct
# что PRON nsubj
# быть VERB acl
# . PUNCT punct
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# это PRON nsubj
# и PART advmod
# есть AUX cop
# счастие NOUN ccomp
# . PUNCT punct
# весь DET det
# сад NOUN nsubj
# наполнялся VERB ROOT
# новый ADJ amod
# , PUNCT punct
# сильный ADJ conj
# аромат NOUN obl
# . PUNCT punct
# месяц NOUN nsubj
# никнул VERB ROOT
# и CCONJ cc
# уходить VERB conj
# с ADP case
# небо NOUN obl
# , PUNCT punct
# но CCONJ cc
# яблони VERB nsubj
# не PART advmod
# темнеть VERB conj
# . PUNCT punct
# они PRON nsubj
# были AUX cop
# белый ADJ ROOT
# не PART advmod
# от ADP case
# лунный ADJ amod
# свет NOUN obl
# . PUNCT punct
#
#
#  SPACE ROOT
# когда SCONJ mark
# пройти VERB advcl
# время NOUN nsubj
# , PUNCT punct
# и CCONJ cc
# весь DET det
# круг NOUN xcomp
# нас PRON obj
# стать VERB conj
# ясный ADJ xcomp
# и CCONJ cc
# холодный ADJ conj
# , PUNCT punct
# небо NOUN nsubj
# позеленело VERB conj
# , PUNCT punct
# и CCONJ cc
# утренний ADJ amod
# сумерки NOUN nsubj
# спуститься VERB conj
# , PUNCT punct
# – PUNCT punct
# я PRON nsubj
# взглянуть VERB parataxis
# близко ADV advmod
# в ADP case
# лицо NOUN obl
# марта PROPN nmod
# , PUNCT punct
# марта PROPN nsubj
# сидеть VERB conj
# все PRON obj
# в ADP case
# тот DET det
# же PART advmod
# положение NOUN obl
# , PUNCT punct
# прижаться VERB advcl
# ко ADP case
# мне PRON obl
# . PUNCT punct
# она PRON nsubj
# поднять VERB ROOT
# глаз NOUN obj
# и CCONJ cc
# улыбнуться VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# пора PROPN parataxis
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# она PRON nsubj
# . PUNCT punct
# – PUNCT punct
# сейчас ADV advmod
# будет VERB ROOT
# солнце NOUN nsubj
# . PUNCT punct
# яблони PROPN nsubj
# цвести VERB ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# что PRON nsubj
# - PRON nsubj
# то PRON nsubj
# ударить VERB ccomp
# меня PRON obj
# в ADP case
# сердце NOUN obl
# . PUNCT punct
# я PRON nsubj
# вспомнить VERB ROOT
# . PUNCT punct
# я PRON nsubj
# побледнеть VERB ROOT
# , PUNCT punct
# в ADP case
# грудь NOUN obl
# стать VERB ccomp
# тяжёлый ADJ xcomp
# и CCONJ cc
# холодный ADJ conj
# . PUNCT punct
# марта NOUN nsubj
# тревожно ADV advmod
# взглянуть VERB ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# что PRON parataxis
# с ADP case
# тобой PRON nmod
# ? PUNCT punct
#
#
#  SPACE conj
# – PUNCT punct
# марта PROPN parataxis
# . PUNCT punct
# я PRON nsubj
# стать VERB ROOT
# несчастный ADJ xcomp
# … PUNCT punct
# пожалей NOUN ROOT
# меня PRON nmod
# … PUNCT punct
# я PRON nsubj
# уезжать VERB ROOT
# … PUNCT punct
#
#
#  SPACE conj
# – PUNCT punct
# уезжать VERB parataxis
# ? PUNCT punct
# – PUNCT punct
# проговорить VERB parataxis
# она PRON nsubj
# медленно ADV advmod
# , PUNCT punct
# без ADP case
# удивление NOUN conj
# . PUNCT punct
# – PUNCT punct
# так ADV advmod
# рано ADV ROOT
# ? PUNCT punct
# подождать VERB ROOT
# . PUNCT punct
# еще ADV advmod
# быть VERB ROOT
# время NOUN nsubj
# . PUNCT punct
# подождать VERB ROOT
# , PUNCT punct
# пока SCONJ mark
# они PRON nsubj
# начать VERB acl
# осыпаться VERB xcomp
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# не PART advmod
# мочь VERB parataxis
# , PUNCT punct
# не PART advmod
# мочь VERB conj
# … PUNCT punct
# я PRON nsubj
# не PART advmod
# сам ADJ amod
# … PUNCT punct
# меня PRON obj
# … PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# ах PROPN parataxis
# , PUNCT punct
# другие ADJ amod
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# она PRON nsubj
# спокойно ADV advmod
# . PUNCT punct
# – PUNCT punct
# они PRON nsubj
# всегда ADV advmod
# мешать VERB ROOT
# , PUNCT punct
# всегда ADV advmod
# , PUNCT punct
# во ADP case
# всем PRON obl
# . PUNCT punct
# ступай PROPN nsubj
# , PUNCT punct
# не PART advmod
# будь AUX cop
# несчастный ADJ ROOT
# . PUNCT punct
# только PART advmod
# я PRON nsubj
# не PART advmod
# хотеть VERB ROOT
# так ADV advmod
# рано ADV advmod
# … PUNCT punct
#
#
#  SPACE punct
# я PRON nsubj
# с ADP case
# тоска NOUN obl
# взглянуть VERB ROOT
# в ADP case
# её DET det
# глаз NOUN obl
# . PUNCT punct
# они PRON nsubj:pass
# были AUX aux:pass
# широко ADV advmod
# раскрыть VERB ROOT
# и CCONJ cc
# покойный ADJ conj
# , PUNCT punct
# только PART advmod
# совсем ADV advmod
# , PUNCT punct
# до ADP case
# край NOUN obl
# , PUNCT punct
# полный ADJ conj
# слеза NOUN obl
# . PUNCT punct
# казаться VERB ROOT
# , PUNCT punct
# если SCONJ mark
# она PRON nsubj
# чуть ADV advmod
# пошевельнуть VERB advcl
# ресница NOUN iobj
# или CCONJ cc
# перевести VERB conj
# взгляд NOUN obj
# , PUNCT punct
# слеза NOUN nsubj
# прольются VERB ccomp
# . PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# встать VERB ROOT
# . PUNCT punct
# она PRON nsubj
# остаться VERB ROOT
# на ADP case
# скамейка NOUN obl
# и CCONJ cc
# не PART advmod
# смотреть VERB conj
# на ADP case
# меня PRON obl
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# прощать VERB parataxis
# , PUNCT punct
# марта PROPN conj
# , PUNCT punct
# – PUNCT punct
# сказать VERB parataxis
# я PRON nsubj
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# прощать VERB parataxis
# . PUNCT punct
# ты PRON nsubj
# не PART advmod
# забудь VERB ROOT
# … PUNCT punct
#
#
#  SPACE conj
# – PUNCT punct
# что PRON parataxis
# ? PUNCT punct
#
#
#  SPACE conj
# – PUNCT punct
# всего ADV parataxis
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# забыть VERB ROOT
# . PUNCT punct
# мы PRON nsubj
# оба NUM nummod:gov
# теперь ADV advmod
# знать VERB ROOT
# , PUNCT punct
# как ADV advmod
# нужный ADJ ccomp
# жить VERB csubj
# . PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# марта PROPN parataxis
# ! PUNCT punct
# но CCONJ cc
# ведь PART advmod
# другие ADJ discourse
# … PUNCT punct
#
#
#  SPACE ROOT
# – PUNCT punct
# да PART parataxis
# , PUNCT punct
# другие ADJ parataxis
# ! PUNCT punct
# а CCONJ cc
# ты PRON nsubj
# не PART advmod
# мочь VERB ROOT
# , PUNCT punct
# ты PRON nsubj
# не PART advmod
# суметь VERB conj
# … PUNCT punct
# все PART advmod
# - PART advmod
# таки PART advmod
# не PART advmod
# забудь VERB ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# взглянуть VERB ccomp
# на ADP case
# нее PRON obl
# , PUNCT punct
# на ADP case
# зелёный ADJ conj
# , PUNCT punct
# совсем ADV advmod
# светлый ADJ conj
# , PUNCT punct
# небо NOUN conj
# , PUNCT punct
# яблони VERB conj
# , PUNCT punct
# точно ADV advmod
# осыпать VERB acl
# снег NOUN obl
# , PUNCT punct
# и CCONJ cc
# сказать VERB conj
# : PUNCT punct
#
#
#  SPACE parataxis
# – PUNCT punct
# не PART advmod
# забыть VERB parataxis
# . PUNCT punct
# прощать VERB ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# она PRON nsubj
# кивнуть VERB ccomp
# мне PRON iobj
# голов NOUN iobj
# . PUNCT punct
# я PRON nsubj
# уйти VERB ROOT
# . PUNCT punct
#
#
#  SPACE ROOT
# x PROPN appos
#
#  SPACE punct
# что PRON nsubj
# случиться VERB ROOT
# дальше ADV advmod
# – PUNCT punct
# я PRON nsubj
# рассказать VERB parataxis
# коротко ADV advmod
# и CCONJ cc
# скоро ADV conj
# , PUNCT punct
# мне PRON iobj
# слишком ADV advmod
# тяжёлый ADJ conj
# . PUNCT punct
# она PRON nsubj
# , PUNCT punct
# мама NOUN appos
# , PUNCT punct
# сделать VERB ROOT
# все PRON obj
# нарочно ADV advmod
# , PUNCT punct
# чтобы SCONJ mark
# отомстить VERB advcl
# мне PRON iobj
# , PUNCT punct
# я PRON nsubj
# знать VERB conj
# . PUNCT punct
# правда ADV parataxis
# , PUNCT punct
# она PRON nsubj
# сама ADJ acl
# в ADP case
# этот DET det
# ночь NOUN obl
# похудеть VERB ROOT
# и CCONJ cc
# осунуться VERB conj
# , PUNCT punct
# но CCONJ cc
# я PRON nsubj
# думать VERB conj
# , PUNCT punct
# от ADP case
# сильный ADJ amod
# ненависть NOUN obl
# ко ADP case
# мне PRON nmod
# . PUNCT punct
# все PRON nsubj
# тут ADV advmod
# сойтись VERB ROOT
# . PUNCT punct
# да PART cc
# я PRON nsubj
# и PART advmod
# знать VERB ROOT
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# простить VERB ccomp
# . PUNCT punct
# она PRON nsubj
# не PART advmod
# мочь VERB ROOT
# простить VERB xcomp
# . PUNCT punct
# я PRON nsubj
# и PART advmod
# не PART advmod
# говорить VERB ROOT
# ей PRON iobj
# ничто PRON obj
# . PUNCT punct
# я PRON nsubj
# был AUX cop
# , PUNCT punct
# как SCONJ case
# мёртвый ADJ ROOT
# . PUNCT punct
# если SCONJ mark
# б AUX aux
# она PRON nsubj
# велеть VERB ROOT
# мне PRON iobj
# взять VERB xcomp
# револьвер NOUN obj
# и CCONJ cc
# застрелиться VERB conj
# – PUNCT punct
# я PRON nsubj
# бы AUX aux
# , PUNCT punct
# молча ADV parataxis
# , PUNCT punct
# взять VERB parataxis
# револьвер NOUN obj
# и CCONJ cc
# застрелиться VERB conj
# . PUNCT punct
# она PRON nsubj
# велеть VERB ROOT
# мне PRON iobj
# уехать VERB xcomp
# одному NUM iobj
# , PUNCT punct
# сказать VERB conj
# , PUNCT punct
# что SCONJ mark
# никогда ADV advmod
# не PART advmod
# увидеть VERB ccomp
# меня PRON obj
# и CCONJ cc
# не PART advmod
# простить VERB conj
# . PUNCT punct
# но CCONJ cc
# я PRON nsubj
# думать VERB ROOT
# , PUNCT punct
# она PRON nsubj
# чувствовать VERB ccomp
# , PUNCT punct
# что SCONJ mark
# не PART advmod
# выдержать VERB ccomp
# и CCONJ cc
# простить VERB conj
# , PUNCT punct
# когда SCONJ mark
# увидеть VERB advcl
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# не PART advmod
# мочь VERB ccomp
# жить VERB xcomp
# ; PUNCT punct
# поэтому ADV advmod
# , PUNCT punct
# чтобы SCONJ mark
# не PART advmod
# изменить VERB advcl
# себя PRON iobj
# , PUNCT punct
# она PRON nsubj
# умереть VERB conj
# нарочно ADV advmod
# . PUNCT punct
# да PART parataxis
# , PUNCT punct
# да PART parataxis
# , PUNCT punct
# я PRON nsubj
# не PART advmod
# сомневаться VERB ROOT
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# это PRON obj
# сделать VERB ccomp
# нарочно ADV advmod
# . PUNCT punct
# доктор NOUN nsubj
# говорить VERB ROOT
# , PUNCT punct
# что SCONJ mark
# у ADP case
# нее PRON obl
# быть VERB ccomp
# дифтерит VERB nsubj
# , PUNCT punct
# но CCONJ cc
# что PRON nsubj
# ж PART advmod
# из ADP case
# это PRON conj
# ? PUNCT punct
# дифтерит NOUN nsubj
# мочь VERB ROOT
# быть VERB xcomp
# , PUNCT punct
# а CCONJ cc
# все PART advmod
# - PART advmod
# таки PART advmod
# она PRON nsubj
# бы AUX aux
# верно ADV advmod
# не PART advmod
# умереть VERB conj
# , PUNCT punct
# если SCONJ mark
# б AUX nsubj
# сильно ADV advmod
# хотеть VERB advcl
# не PART advmod
# умереть VERB xcomp
# . PUNCT punct
# я PRON nsubj
# приехать VERB ROOT
# из ADP case
# москва PROPN obl
# на ADP case
# третий ADJ amod
# день NOUN obl
# после ADP case
# смерть NOUN nmod
# . PUNCT punct
# она PRON nsubj
# уже ADV advmod
# стать VERB ROOT
# разлагаться VERB xcomp
# . PUNCT punct
# такой DET det
# уксусный ADJ amod
# и CCONJ cc
# страшный ADJ conj
# запах NOUN nsubj
# идти VERB ROOT
# от ADP case
# нее PRON obl
# . PUNCT punct
# я PRON nsubj
# посмотреть VERB ROOT
# ей PRON iobj
# в ADP case
# лицо NOUN obl
# и CCONJ cc
# ничто PRON obj
# не PART advmod
# сказать VERB conj
# . PUNCT punct
#
#
#  SPACE ROOT
# какой DET det
# - DET det
# то DET det
# господин NOUN nsubj
# подойти VERB ccomp
# ко ADP case
# мне PRON obl
# , PUNCT punct
# долго ADV advmod
# жать VERB conj
# рука NOUN obj
# , PUNCT punct
# просить VERB conj
# подкрепиться VERB xcomp
# и CCONJ cc
# сказать VERB conj
# : PUNCT punct
#
#
#  SPACE parataxis
# – PUNCT punct
# да PART parataxis
# , PUNCT punct
# ваш DET det
# матушка NOUN nsubj
# была AUX cop
# удивительный ADJ amod
# женщина NOUN conj
# . PUNCT punct
# как SCONJ mark
# вы PRON nsubj:pass
# должный ADJ ROOT
# быть AUX aux:pass
# потрясти VERB xcomp
# ! PUNCT punct
# у ADP case
# вас PRON obl
# были AUX ROOT
# с ADP case
# нею PRON obl
# удивительный ADJ amod
# отношение NOUN nsubj
# … PUNCT punct
#
#
#  SPACE ROOT
# я PRON nsubj
# неестественно ADV advmod
# рассмеяться VERB conj
# и CCONJ cc
# сказать VERB conj
# : PUNCT punct
#
#
#  SPACE parataxis
# – PUNCT punct
# да PART parataxis
# , PUNCT punct
# да PART parataxis
# , PUNCT punct
# вы PRON nsubj
# правый ADJ conj
# … PUNCT punct
#
#
#  SPACE punct
# и CCONJ cc
# сам ADJ acl
# пожать VERB ROOT
# рука NOUN obj
# господин NOUN iobj
# . PUNCT punct
#
#
#  SPACE ROOT
# потом ADV advmod
# ее PRON obj
# похоронить VERB conj
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# уехать VERB conj
# . PUNCT punct
# зачем ADV advmod
# бы AUX aux
# я PRON nsubj
# там ADV advmod
# остаться VERB ROOT
# ? PUNCT punct
# о ADP case
# март PROPN obl
# я PRON nsubj
# не PART advmod
# спросить VERB ROOT
# , PUNCT punct
# в ADP case
# сад NOUN obl
# не PART advmod
# заходить VERB conj
# … PUNCT punct
#
#
#  SPACE conj
# и CCONJ cc
# пройти VERB conj
# сколько ADV nummod:gov
# - ADV nummod:gov
# то DET det
# год NOUN obl
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# помнить VERB ROOT
# теперь ADV advmod
# хороший ADJ advmod
# – PUNCT punct
# сколько NUM parataxis
# . PUNCT punct
# я PRON nsubj
# не PART advmod
# помнить VERB ROOT
# , PUNCT punct
# как SCONJ mark
# я PRON nsubj
# жить VERB ccomp
# . PUNCT punct
# я PRON nsubj
# все DET det
# стать VERB ROOT
# забывать VERB xcomp
# . PUNCT punct
# порой ADV advmod
# , PUNCT punct
# впрочем ADV parataxis
# , PUNCT punct
# я PRON nsubj
# вспоминать VERB ROOT
# тот DET det
# ночь NOUN obj
# , PUNCT punct
# когда ADV mark
# распускались VERB acl:relcl
# яблони NOUN nsubj
# . PUNCT punct
# сажусь VERB ROOT
# за ADP case
# рояль NOUN obl
# и CCONJ cc
# играть VERB conj
# маленький ADJ amod
# песенка NOUN obj
# : PUNCT punct
# " PUNCT punct
# ни CCONJ cc
# слово NOUN parataxis
# , PUNCT punct
# о ADP case
# друг PRON conj
# мой DET det
# " PUNCT punct
# … PUNCT punct
# мне PRON iobj
# делаться VERB ROOT
# светлее ADV advmod
# . PUNCT punct
#
#
#  SPACE ROOT
# но CCONJ cc
# это PRON nsubj
# редко ADV advmod
# ; PUNCT punct
# я PRON nsubj
# редко ADV advmod
# мочь VERB conj
# вспоминать VERB xcomp
# … PUNCT punct
# и CCONJ cc
# с ADP case
# каждый DET det
# час NOUN obl
# прибавляться VERB ROOT
# тяжесть NOUN nsubj
# жизнь NOUN nmod
# . PUNCT punct
# я PRON nsubj
# жить VERB ROOT
# , PUNCT punct
# потому ADV mark
# что SCONJ fixed
# не PART advmod
# иметь VERB advcl
# сила NOUN obj
# даже PART advmod
# умереть VERB xcomp
# . PUNCT punct
# жить VERB ROOT
# в ADP case
# петербург PROPN obl
# , PUNCT punct
# один NUM conj
# , PUNCT punct
# в ADP case
# тёмный ADJ amod
# и CCONJ cc
# пропахшей ADJ conj
# кухня NOUN amod
# квартира NOUN iobj
# , PUNCT punct
# давать VERB conj
# свой DET det
# ненужный ADJ amod
# урок NOUN obj
# музыка NOUN nmod
# и CCONJ cc
# ненужно ADV advmod
# возвращаться VERB conj
# домой ADV advmod
# . PUNCT punct
# сколько NUM nummod:gov
# время NOUN obl
# это PRON nsubj
# еще ADV advmod
# будет AUX aux
# продолжаться VERB ROOT
# ? PUNCT punct
#
#
#  SPACE ROOT
# посредине NOUN iobj
# потолок NOUN nmod
# , PUNCT punct
# в ADP case
# большой ADJ amod
# комната NOUN obl
# , PUNCT punct
# быть VERB conj
# крюк NOUN nsubj
# … PUNCT punct
# я PRON nsubj
# уж PART advmod
# говорить VERB ROOT
# о ADP case
# нем PRON obl
# . PUNCT punct
# так ADV advmod
# вот PART advmod
# мне PRON iobj
# приходить VERB ROOT
# мысль NOUN nsubj
# : PUNCT punct
# что SCONJ parataxis
# , PUNCT punct
# если SCONJ mark
# я PRON nsubj
# принесу VERB advcl
# из ADP case
# передний ADJ amod
# верёвка NOUN obl
# от ADP case
# чемодан NOUN obl
# и CCONJ cc
# закину NOUN conj
# ее PRON obj
# на ADP case
# крюк NOUN nmod
# ? PUNCT punct
# ведь PART advmod
# никто PRON nsubj
# даже PART advmod
# и PART advmod
# не PART advmod
# узнавать VERB ROOT
# , PUNCT punct
# особенно ADV advmod
# теперь ADV advmod
# , PUNCT punct
# ночь NOUN conj
# … PUNCT punct
# старуха NOUN nsubj
# , PUNCT punct
# мой DET det
# кухарка NOUN conj
# , PUNCT punct
# спать VERB ROOT
# . PUNCT punct
# и CCONJ cc
# главный ADJ parataxis
# , PUNCT punct
# ничто PRON nsubj
# не PART advmod
# сделаться VERB ROOT
# от ADP case
# того PRON obl
# , PUNCT punct
# что SCONJ mark
# я PRON nsubj
# закинуть VERB acl
# верёвка NOUN obj
# на ADP case
# крюк NOUN nmod
# . PUNCT punct
# ее PRON iobj
# можно ADV ROOT
# снять VERB csubj
# и CCONJ cc
# снести VERB conj
# обратно ADV advmod
# в ADP case
# передний ADJ obl
# . PUNCT punct
# даже PART advmod
# если SCONJ mark
# я PRON nsubj
# петлю VERB obj
# сделать VERB ROOT
# – PUNCT punct
# и CCONJ cc
# то SCONJ mark
# ничто PRON nsubj
# ровно ADV advmod
# не PART advmod
# случиться VERB parataxis
# , PUNCT punct
# ведь SCONJ mark
# не PART advmod
# повеситься VERB advcl
# же PART advmod
# , PUNCT punct
# ведь SCONJ mark
# не PART advmod
# должный ADJ advcl
# же PART advmod
# я PRON nsubj
# , PUNCT punct
# оттого ADV mark
# что SCONJ fixed
# сделать VERB xcomp
# петля NOUN obj
# , PUNCT punct
# непременно ADV advmod
# повеситься VERB conj
# ? PUNCT punct
# это PRON nsubj
# так ADV advmod
# ужасный ADJ ROOT
# , PUNCT punct
# так ADV advmod
# некрасивый ADJ conj
# … PUNCT punct
# как ADV mark
# я PRON nsubj
# далеко ADV ROOT
# от ADP case
# марта PROPN obl
# ! PUNCT punct
# .. PUNCT punct
# но CCONJ cc
# разве PART advmod
# я PRON nsubj
# в ADP case
# самом ADJ amod
# дело NOUN ROOT
# ? PUNCT punct
# .. PUNCT punct
# нет PART parataxis
# , PUNCT punct
# нет VERB ROOT
# , PUNCT punct
# я PRON nsubj
# только PART advmod
# попробую VERB conj
# , PUNCT punct
# никто PRON nsubj
# не PART advmod
# узнавать VERB conj
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# попробовать VERB conj
# … PUNCT punct

# %% [markdown]
# ## Practicing with the example text
# When working with languages that have inflection, we typically use `token.lemma_` instead of `token.text` like you'll find in the English examples. This is important when we're counting, so that differently-inflected forms of a word (e.g. masculine vs. feminine or singular vs. plural) aren't counted as if they were different words.

# %%
filepath = "../texts/ru.txt"
document = nlp(open(filepath, encoding="utf-8").read())

# %% [markdown]
# ## Get Adjectives

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |

# %% [markdown]
# To extract and count the adjectives in the example text, we will follow the same model as above, except we'll add an `if` statement that will pull out words only if their POS label matches "ADJ."

# %% [markdown]
# :::{admonition} Python Review
# :class: pythonreview
#
# While we demonstrate how to extract parts of speech in the sections below, we're also going to reinforce some integral Python skills. Notice how we use `for` loops and `if` statements to `.append()` specific words to a list. Then we count the words in the list and make a pandas dataframe from the list.
# :::

# %% [markdown]
# Here we make a list of the adjectives identified in the example text:

# %%
adjs = []
for token in document:
    if token.pos_ == 'ADJ':
        adjs.append(token.lemma_)

# %%
adjs
# Out:
# ['виноватый',
#  'странный',
#  'неодетый',
#  'двадцатиградусный',
#  'хороший',
#  'лёгкий',
#  'последний',
#  'важный',
#  'значительный',
#  'прямой',
#  'унылый',
#  'быстрый',
#  'однообразный',
#  'нужный',
#  'старый',
#  'сам',
#  'красивый',
#  'нежный',
#  'похожий',
#  'больший',
#  'жёлтый',
#  'тёмный',
#  'должный',
#  'последний',
#  'пошлый',
#  'трусливый',
#  'хороший',
#  'порядочный',
#  'хороший',
#  'длинный',
#  'трудный',
#  'холодный',
#  'самые',
#  'обыденный',
#  'скучный',
#  'прекрасный',
#  'сентиментальный',
#  'трудный',
#  'тихий',
#  'глубокий',
#  'пожилой',
#  'первый',
#  'толковый',
#  'маленький',
#  'простой',
#  'малороссийский',
#  'далёкий',
#  'тёмный',
#  'тёплый',
#  'милый',
#  'невольный',
#  'радостный',
#  'другие',
#  'светлый',
#  'ii',
#  'скучный',
#  'самого',
#  'счастливый',
#  'должный',
#  'печальный',
#  'пожилой',
#  'другой',
#  'молодой',
#  'тоненький',
#  'больший',
#  'чёрный',
#  'свежий',
#  'блестящий',
#  'быстрый',
#  'странный',
#  'самую',
#  'ранний',
#  'необычный',
#  'светлый',
#  'другого',
#  'хороший',
#  'низкий',
#  'тёмный',
#  'равный',
#  'большой',
#  'новый',
#  'неудобный',
#  'холодный',
#  'небольшой',
#  'чистый',
#  'чужой',
#  'бесконечный',
#  'самом',
#  'сама',
#  'хороший',
#  'гимназический',
#  'нарядный',
#  'весёлый',
#  'счастливый',
#  'хорошенький',
#  'похожий',
#  'маленький',
#  'гимназический',
#  'знаменитый',
#  'хороший',
#  'возможный',
#  'влюблены',
#  'должный',
#  'влюблены',
#  'красивый',
#  'похожий',
#  'должный',
#  'сама',
#  'мужской',
#  'чужой',
#  'сама',
#  'похожий',
#  'хороший',
#  'похожий',
#  'сама',
#  'нехороший',
#  'похожий',
#  'красивый',
#  'нежный',
#  'простой',
#  'виноватый',
#  'мужественный',
#  'должный',
#  'большой',
#  'красивый',
#  'бесчисленный',
#  'звенящий',
#  'тамошний',
#  'пошлый',
#  'вечный',
#  'бесцельный',
#  'сам',
#  'чистый',
#  'редкий',
#  'хороший',
#  'других',
#  'чистый',
#  'чистый',
#  'пошлый',
#  'праздный',
#  'iii',
#  'удивительный',
#  'рад',
#  'старый',
#  'скучный',
#  'хорошенький',
#  'малый',
#  'никитский',
#  'молодой',
#  'странный',
#  'талантливый',
#  'молодой',
#  'должный',
#  'трудный',
#  'нужный',
#  'синий',
#  'больной',
#  'солнечный',
#  'беспокойный',
#  'хороший',
#  'настоящий',
#  'невольный',
#  'молодой',
#  'недовольный',
#  'неважный',
#  'должный',
#  'первый',
#  'первый',
#  'iv',
#  'сам',
#  'довольный',
#  'трескучий',
#  'самое',
#  'тайный',
#  'самое',
#  'тайный',
#  'самое',
#  'глубокий',
#  'равный',
#  'равный',
#  'сам',
#  'умный',
#  'умный',
#  'другое',
#  'другая',
#  'необходимый',
#  'нервный',
#  'главный',
#  'слабый',
#  'слабый',
#  'последний',
#  'сам',
#  'лишний',
#  'лишний',
#  'равный',
#  'целый',
#  'довольный',
#  'небольшой',
#  'голубой',
#  'голый',
#  'весёлый',
#  'чёрный',
#  'дальний',
#  'первый',
#  'светлый',
#  'молодой',
#  'жёлтый',
#  'крошечный',
#  'первый',
#  'любопытный',
#  'неловкий',
#  'серый',
#  'холодный',
#  'странный',
#  'сам',
#  'жёлтый',
#  'светлый',
#  'весенний',
#  'весенний',
#  'круглый',
#  'крепкий',
#  'нужный',
#  'нужный',
#  'страшный',
#  'узенький',
#  'сырой',
#  'низкий',
#  'самого',
#  'дальний',
#  'живой',
#  'чёрный',
#  'чужой',
#  'обрывистый',
#  'глубокий',
#  'сизый',
#  'далёкий',
#  'чужой',
#  'связный',
#  'высоко',
#  'равный',
#  'весенний',
#  'спокойный',
#  'чужой',
#  'равнодушный',
#  'незнакомый',
#  'робко',
#  'видный',
#  'первый',
#  'странный',
#  'обыкновенный',
#  'маскарадный',
#  'простой',
#  'возможный',
#  'широкий',
#  'мягкий',
#  'белый',
#  'широкий',
#  'другой',
#  'узкий',
#  'темно',
#  '-',
#  'красный',
#  'странный',
#  'длинный',
#  'небрежный',
#  'красивый',
#  'узкий',
#  'длинный',
#  'воспитанный',
#  'молодой',
#  'другими',
#  'странный',
#  'красивый',
#  'сама',
#  'русский',
#  'русский',
#  'слепой',
#  'богатый',
#  'молоденький',
#  'странный',
#  'красивый',
#  'красивый',
#  'красивый',
#  'красивый',
#  'нежный',
#  'душистый',
#  'розовый',
#  'предвечерний',
#  'высокомерный',
#  'связный',
#  'последний',
#  'странный',
#  'противный',
#  'резкий',
#  'определённый',
#  'первый',
#  'настоящий',
#  'vi',
#  'сам',
#  'должный',
#  'бледный',
#  'больший',
#  'третий',
#  'слабый',
#  'твёрдый',
#  'жёлтый',
#  'крошечный',
#  'зелёный',
#  'знакомый',
#  'красный',
#  'золотой',
#  'равный',
#  'розовый',
#  'странный',
#  'тёмный',
#  'яркий',
#  'простой',
#  'небрежный',
#  'бледный',
#  'тонкий',
#  'продолговатый',
#  'бледный',
#  'прозрачный',
#  'чистый',
#  'синий',
#  'тоненький',
#  'прямой',
#  'светло',
#  '-',
#  'розовый',
#  'рад',
#  'полный',
#  'левый',
#  'резкий',
#  'составной',
#  'разный',
#  'хороший',
#  'верный',
#  'простой',
#  'нескорый',
#  'хороший',
#  'непонятный',
#  'петербургской',
#  'тёмный',
#  'черно',
#  '-',
#  'серый',
#  'большой',
#  'угрюмый',
#  'ужасный',
#  'гадкий',
#  'невозможный',
#  'другого',
#  'случайный',
#  'трудный',
#  'другие',
#  'второй',
#  'тихий',
#  'простой',
#  'несложный',
#  'лишний',
#  'хороший',
#  'весенний',
#  'жёлтый',
#  'вечерний',
#  'сам',
#  'хороший',
#  'тёмный',
#  'светлый',
#  'неясный',
#  'молодой',
#  'должный',
#  'хороший',
#  'первый',
#  'первый',
#  'последний',
#  'нужный',
#  'сам',
#  'вялый',
#  'бледный',
#  'потемневшими',
#  'неожиданный',
#  'следующий',
#  'больший',
#  'собственный',
#  'большой',
#  'неожиданный',
#  'бессмысленный',
#  'безнадёжный',
#  'первый',
#  'лёгкий',
#  'влюблен',
#  'должный',
#  'должный',
#  'безумный',
#  'умный',
#  'сам',
#  'безнадёжный',
#  'инстинктивный',
#  'готовый',
#  'тяжёлый',
#  'хороший',
#  'сам',
#  'таковы',
#  '-',
#  'нежный',
#  'последний',
#  'сама',
#  'дурной',
#  'равный',
#  'справедливый',
#  'способный',
#  'странный',
#  'должный',
#  'слабенький',
#  'потерпи',
#  'хороший',
#  'должный',
#  'тяжёлый',
#  'больной',
#  'сама',
#  'мёртвый',
#  'полузакрытыми',
#  'равный',
#  'круглый',
#  'большой',
#  'серый',
#  'угловой',
#  'полоцким',
#  'здоровый',
#  'жестокий',
#  'больший',
#  'сильный',
#  'неизбежный',
#  'лёгкий',
#  'радостный',
#  'смешанный',
#  'разнородный',
#  'стыдный',
#  'белый',
#  'розовый',
#  'должный',
#  'белый',
#  'маленький',
#  'высоко',
#  'сами',
#  'рад',
#  'короткий',
#  'робкий',
#  'неумелый',
#  'неясный',
#  'крепкий',
#  'безмолвный',
#  'неподвижный',
#  'видный',
#  'невидный',
#  'лунный',
#  'высоко',
#  'холодный',
#  'страшный',
#  'жуткий',
#  'холодный',
#  'близкий',
#  'спокойный',
#  'спокойный',
#  'бледный',
#  'должный',
#  'должный',
#  'близкий',
#  'близкий',
#  'новый',
#  'неясный',
#  'первый',
#  'другие',
#  'рад',
#  'новый',
#  'сильный',
#  'белый',
#  'лунный',
#  'ясный',
#  'холодный',
#  'утренний',
#  'тяжёлый',
#  'холодный',
#  'несчастный',
#  'сам',
#  'другие',
#  'несчастный',
#  'покойный',
#  'полный',
#  'нужный',
#  'другие',
#  'другие',
#  'зелёный',
#  'светлый',
#  'тяжёлый',
#  'сама',
#  'сильный',
#  'мёртвый',
#  'третий',
#  'уксусный',
#  'страшный',
#  'удивительный',
#  'должный',
#  'удивительный',
#  'правый',
#  'сам',
#  'хороший',
#  'маленький',
#  'тёмный',
#  'пропахшей',
#  'ненужный',
#  'большой',
#  'передний',
#  'главный',
#  'передний',
#  'должный',
#  'ужасный',
#  'некрасивый',
#  'самом']

# %% [markdown]
# Then we count the unique adjectives in this list with the `Counter()` module:

# %%
adjs_tally = Counter(adjs)

# %%
adjs_tally.most_common()
# Out:
# [('должный', 18),
#  ('хороший', 17),
#  ('сам', 13),
#  ('странный', 11),
#  ('первый', 11),
#  ('красивый', 10),
#  ('равный', 8),
#  ('сама', 8),
#  ('тёмный', 7),
#  ('холодный', 7),
#  ('молодой', 7),
#  ('последний', 6),
#  ('нужный', 6),
#  ('похожий', 6),
#  ('простой', 6),
#  ('другие', 6),
#  ('светлый', 6),
#  ('большой', 6),
#  ('больший', 5),
#  ('жёлтый', 5),
#  ('чистый', 5),
#  ('чужой', 5),
#  ('бледный', 5),
#  ('нежный', 4),
#  ('трудный', 4),
#  ('маленький', 4),
#  ('рад', 4),
#  ('весенний', 4),
#  ('белый', 4),
#  ('-', 4),
#  ('розовый', 4),
#  ('тяжёлый', 4),
#  ('лёгкий', 3),
#  ('пошлый', 3),
#  ('длинный', 3),
#  ('скучный', 3),
#  ('глубокий', 3),
#  ('чёрный', 3),
#  ('новый', 3),
#  ('удивительный', 3),
#  ('самое', 3),
#  ('умный', 3),
#  ('слабый', 3),
#  ('лишний', 3),
#  ('серый', 3),
#  ('страшный', 3),
#  ('высоко', 3),
#  ('спокойный', 3),
#  ('неясный', 3),
#  ('сильный', 3),
#  ('близкий', 3),
#  ('виноватый', 2),
#  ('прямой', 2),
#  ('быстрый', 2),
#  ('старый', 2),
#  ('тихий', 2),
#  ('пожилой', 2),
#  ('далёкий', 2),
#  ('невольный', 2),
#  ('радостный', 2),
#  ('самого', 2),
#  ('счастливый', 2),
#  ('другой', 2),
#  ('тоненький', 2),
#  ('другого', 2),
#  ('низкий', 2),
#  ('небольшой', 2),
#  ('самом', 2),
#  ('гимназический', 2),
#  ('весёлый', 2),
#  ('хорошенький', 2),
#  ('возможный', 2),
#  ('влюблены', 2),
#  ('синий', 2),
#  ('больной', 2),
#  ('настоящий', 2),
#  ('довольный', 2),
#  ('тайный', 2),
#  ('главный', 2),
#  ('дальний', 2),
#  ('крошечный', 2),
#  ('круглый', 2),
#  ('крепкий', 2),
#  ('связный', 2),
#  ('видный', 2),
#  ('широкий', 2),
#  ('узкий', 2),
#  ('красный', 2),
#  ('небрежный', 2),
#  ('русский', 2),
#  ('резкий', 2),
#  ('третий', 2),
#  ('зелёный', 2),
#  ('полный', 2),
#  ('ужасный', 2),
#  ('неожиданный', 2),
#  ('безнадёжный', 2),
#  ('мёртвый', 2),
#  ('лунный', 2),
#  ('несчастный', 2),
#  ('передний', 2),
#  ('неодетый', 1),
#  ('двадцатиградусный', 1),
#  ('важный', 1),
#  ('значительный', 1),
#  ('унылый', 1),
#  ('однообразный', 1),
#  ('трусливый', 1),
#  ('порядочный', 1),
#  ('самые', 1),
#  ('обыденный', 1),
#  ('прекрасный', 1),
#  ('сентиментальный', 1),
#  ('толковый', 1),
#  ('малороссийский', 1),
#  ('тёплый', 1),
#  ('милый', 1),
#  ('ii', 1),
#  ('печальный', 1),
#  ('свежий', 1),
#  ('блестящий', 1),
#  ('самую', 1),
#  ('ранний', 1),
#  ('необычный', 1),
#  ('неудобный', 1),
#  ('бесконечный', 1),
#  ('нарядный', 1),
#  ('знаменитый', 1),
#  ('мужской', 1),
#  ('нехороший', 1),
#  ('мужественный', 1),
#  ('бесчисленный', 1),
#  ('звенящий', 1),
#  ('тамошний', 1),
#  ('вечный', 1),
#  ('бесцельный', 1),
#  ('редкий', 1),
#  ('других', 1),
#  ('праздный', 1),
#  ('iii', 1),
#  ('малый', 1),
#  ('никитский', 1),
#  ('талантливый', 1),
#  ('солнечный', 1),
#  ('беспокойный', 1),
#  ('недовольный', 1),
#  ('неважный', 1),
#  ('iv', 1),
#  ('трескучий', 1),
#  ('другое', 1),
#  ('другая', 1),
#  ('необходимый', 1),
#  ('нервный', 1),
#  ('целый', 1),
#  ('голубой', 1),
#  ('голый', 1),
#  ('любопытный', 1),
#  ('неловкий', 1),
#  ('узенький', 1),
#  ('сырой', 1),
#  ('живой', 1),
#  ('обрывистый', 1),
#  ('сизый', 1),
#  ('равнодушный', 1),
#  ('незнакомый', 1),
#  ('робко', 1),
#  ('обыкновенный', 1),
#  ('маскарадный', 1),
#  ('мягкий', 1),
#  ('темно', 1),
#  ('воспитанный', 1),
#  ('другими', 1),
#  ('слепой', 1),
#  ('богатый', 1),
#  ('молоденький', 1),
#  ('душистый', 1),
#  ('предвечерний', 1),
#  ('высокомерный', 1),
#  ('противный', 1),
#  ('определённый', 1),
#  ('vi', 1),
#  ('твёрдый', 1),
#  ('знакомый', 1),
#  ('золотой', 1),
#  ('яркий', 1),
#  ('тонкий', 1),
#  ('продолговатый', 1),
#  ('прозрачный', 1),
#  ('светло', 1),
#  ('левый', 1),
#  ('составной', 1),
#  ('разный', 1),
#  ('верный', 1),
#  ('нескорый', 1),
#  ('непонятный', 1),
#  ('петербургской', 1),
#  ('черно', 1),
#  ('угрюмый', 1),
#  ('гадкий', 1),
#  ('невозможный', 1),
#  ('случайный', 1),
#  ('второй', 1),
#  ('несложный', 1),
#  ('вечерний', 1),
#  ('вялый', 1),
#  ('потемневшими', 1),
#  ('следующий', 1),
#  ('собственный', 1),
#  ('бессмысленный', 1),
#  ('влюблен', 1),
#  ('безумный', 1),
#  ('инстинктивный', 1),
#  ('готовый', 1),
#  ('таковы', 1),
#  ('дурной', 1),
#  ('справедливый', 1),
#  ('способный', 1),
#  ('слабенький', 1),
#  ('потерпи', 1),
#  ('полузакрытыми', 1),
#  ('угловой', 1),
#  ('полоцким', 1),
#  ('здоровый', 1),
#  ('жестокий', 1),
#  ('неизбежный', 1),
#  ('смешанный', 1),
#  ('разнородный', 1),
#  ('стыдный', 1),
#  ('сами', 1),
#  ('короткий', 1),
#  ('робкий', 1),
#  ('неумелый', 1),
#  ('безмолвный', 1),
#  ('неподвижный', 1),
#  ('невидный', 1),
#  ('жуткий', 1),
#  ('ясный', 1),
#  ('утренний', 1),
#  ('покойный', 1),
#  ('уксусный', 1),
#  ('правый', 1),
#  ('пропахшей', 1),
#  ('ненужный', 1),
#  ('некрасивый', 1)]

# %% [markdown]
# Then we make a dataframe from this list:

# %%
df = pd.DataFrame(adjs_tally.most_common(), columns=['adj', 'count'])
df[:100]
# Out:
#               adj  count
# 0         должный     18
# 1         хороший     17
# 2             сам     13
# 3        странный     11
# 4          первый     11
# 5        красивый     10
# 6          равный      8
# 7            сама      8
# 8          тёмный      7
# 9        холодный      7
# 10        молодой      7
# 11      последний      6
# 12         нужный      6
# 13        похожий      6
# 14        простой      6
# 15         другие      6
# 16        светлый      6
# 17        большой      6
# 18        больший      5
# 19         жёлтый      5
# 20         чистый      5
# 21          чужой      5
# 22        бледный      5
# 23         нежный      4
# 24        трудный      4
# 25      маленький      4
# 26            рад      4
# 27       весенний      4
# 28          белый      4
# 29              -      4
# 30        розовый      4
# 31        тяжёлый      4
# 32         лёгкий      3
# 33         пошлый      3
# 34        длинный      3
# 35        скучный      3
# 36       глубокий      3
# 37         чёрный      3
# 38          новый      3
# 39   удивительный      3
# 40          самое      3
# 41          умный      3
# 42         слабый      3
# 43         лишний      3
# 44          серый      3
# 45       страшный      3
# 46         высоко      3
# 47      спокойный      3
# 48        неясный      3
# 49        сильный      3
# 50        близкий      3
# 51      виноватый      2
# 52         прямой      2
# 53        быстрый      2
# 54         старый      2
# 55          тихий      2
# 56        пожилой      2
# 57        далёкий      2
# 58      невольный      2
# 59      радостный      2
# 60         самого      2
# 61     счастливый      2
# 62         другой      2
# 63      тоненький      2
# 64        другого      2
# 65         низкий      2
# 66      небольшой      2
# 67          самом      2
# 68  гимназический      2
# 69        весёлый      2
# 70    хорошенький      2
# 71      возможный      2
# 72       влюблены      2
# 73          синий      2
# 74        больной      2
# 75      настоящий      2
# 76      довольный      2
# 77         тайный      2
# 78        главный      2
# 79        дальний      2
# 80      крошечный      2
# 81        круглый      2
# 82        крепкий      2
# 83        связный      2
# 84         видный      2
# 85        широкий      2
# 86          узкий      2
# 87        красный      2
# 88      небрежный      2
# 89        русский      2
# 90         резкий      2
# 91         третий      2
# 92        зелёный      2
# 93         полный      2
# 94        ужасный      2
# 95    неожиданный      2
# 96    безнадёжный      2
# 97        мёртвый      2
# 98         лунный      2
# 99     несчастный      2

# %% [markdown]
# ## Get Nouns

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |

# %% [markdown]
# To extract and count nouns, we can follow the same model as above, except we will change our `if` statement to check for POS labels that match "NOUN".

# %%
nouns = []
for token in document:
    if token.pos_ == 'NOUN':
        nouns.append(token.lemma_)

nouns_tally = Counter(nouns)

df = pd.DataFrame(nouns_tally.most_common(), columns=['noun', 'count'])
df[:100]
# Out:
#              noun  count
# 0             сад     33
# 1            мама     31
# 2            глаз     15
# 3            небо     15
# 4            день     14
# 5             раз     13
# 6           слово     12
# 7         человек     11
# 8             год     10
# 9          солнце     10
# 10          жизнь      9
# 11         платье      9
# 12          весна      9
# 13       изгородь      9
# 14           рука      8
# 15        комната      8
# 16          время      8
# 17         минута      8
# 18           лицо      7
# 19         сердце      7
# 20           отец      7
# 21          вечер      7
# 22        барышня      7
# 23           сила      7
# 24           окно      7
# 25         цветок      7
# 26        счастие      6
# 27         воздух      6
# 28           свет      6
# 29        женщина      6
# 30          земля      6
# 31         яблони      6
# 32          мысль      5
# 33           душа      5
# 34            дом      5
# 35          запах      5
# 36         музыка      5
# 37         дерево      5
# 38         яблоня      5
# 39        дорожка      5
# 40          шорох      5
# 41            час      5
# 42          месяц      5
# 43        чувство      4
# 44       господин      4
# 45           пора      4
# 46      отношение      4
# 47       квартира      4
# 48  консерватория      4
# 49           цвет      4
# 50          конец      4
# 51          рояль      4
# 52           гора      4
# 53            луч      4
# 54       скамейка      4
# 55            шаг      4
# 56           ночь      4
# 57          мотив      4
# 58           утро      4
# 59           крюк      4
# 60           мать      3
# 61           фуга      3
# 62   воспоминание      3
# 63       прелюдия      3
# 64        концерт      3
# 65          слеза      3
# 66        ребёнок      3
# 67           двор      3
# 68           дело      3
# 69         одежда      3
# 70          почка      3
# 71          голов      3
# 72           тень      3
# 73           пояс      3
# 74           звук      3
# 75          голос      3
# 76          шёпот      3
# 77   возлюбленной      2
# 78          тепло      2
# 79       половина      2
# 80         дорога      2
# 81         борода      2
# 82           воля      2
# 83         тишина      2
# 84        песенка      2
# 85         облако      2
# 86        прошлое      2
# 87        мальчик      2
# 88          театр      2
# 89           урок      2
# 90       движение      2
# 91          целое      2
# 92        сторона      2
# 93          книга      2
# 94        экзамен      2
# 95        желание      2
# 96         многие      2
# 97         многое      2
# 98       экономка      2
# 99      профессор      2

# %% [markdown]
# ## Get Verbs

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |

# %% [markdown]
# To extract and count works of art, we can follow a similar-ish model to the examples above. This time, however, we're going to make our code even more economical and efficient (while still changing our `if` statement to match the POS label "VERB").

# %% [markdown]
# :::{admonition} Python Review
# :class: pythonreview
#
# We can use a [*list comprehension*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/More-Lists-Loops.html#List-Comprehensions) to get our list of verbs in a single line of code! Closely examine the first line of code below:
# :::

# %%
verbs = [token.lemma_ for token in document if token.pos_ == 'VERB']

verbs_tally = Counter(verbs)

df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#             verb  count
# 0           мочь     49
# 1          знать     47
# 2           быть     46
# 3        сказать     37
# 4       говорить     31
# 5         думать     27
# 6         любить     25
# 7          стать     24
# 8           жить     20
# 9       казаться     20
# 10        хотеть     18
# 11        играть     16
# 12      смотреть     16
# 13       сделать     14
# 14   чувствовать     13
# 15          идти     12
# 16           нет     11
# 17         пойти     11
# 18        понять     11
# 19        видеть     10
# 20       умереть      9
# 21      понимать      9
# 22      спросить      9
# 23    заниматься      8
# 24     нравиться      8
# 25        прийти      8
# 26        сидеть      8
# 27         ждать      7
# 28        забыть      7
# 29        встать      7
# 30          уйти      7
# 31      простить      7
# 32       слышать      7
# 33       молчать      7
# 34      хотеться      6
# 35        бывать      6
# 36      выходить      6
# 37        гулять      6
# 38      делаться      6
# 39        ходить      6
# 40         будет      6
# 41        пройти      6
# 42     вспомнить      6
# 43     приходить      6
# 44     взглянуть      6
# 45  рассказывать      5
# 46       увидеть      5
# 47       слушать      5
# 48       поехать      5
# 49        володя      5
# 50        уехать      5
# 51         сесть      5
# 52       подойти      5
# 53       помнить      5
# 54         уметь      4
# 55         иметь      4
# 56       бояться      4
# 57     ухаживать      4
# 58    измениться      4
# 59     прибавить      4
# 60      подумать      4
# 61    вспоминать      4
# 62      страдать      4
# 63      услышать      4
# 64    посмотреть      4
# 65        стоять      4
# 66   проговорить      4
# 67       прощать      4
# 68    показаться      4
# 69     случиться      4
# 70      остаться      4
# 71      написать      3
# 72       умирать      3
# 73    рассказать      3
# 74         дойти      3
# 75    покориться      3
# 76        верить      3
# 77        давать      3
# 78     стыдиться      3
# 79        делать      3
# 80       бросить      3
# 81        скрыть      3
# 82       уезжать      3
# 83   сомневаться      3
# 84       учиться      3
# 85         ехать      3
# 86       сойтись      3
# 87        суметь      3
# 88         смочь      3
# 89       плакать      3
# 90      приехать      3
# 91    испугаться      3
# 92     удивиться      3
# 93       уходить      3
# 94         взять      3
# 95    продолжать      3
# 96     повторить      3
# 97      жениться      3
# 98         ожить      3
# 99        обнять      3

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ## Get Sentences with Keyword

# %% [markdown]
# spaCy can also identify sentences in a document. To access sentences, we can iterate through `document.sents` and pull out the `.text` of each sentence.

# %% [markdown]
# We can use spaCy's sentence-parsing capabilities to extract sentences that contain particular keywords, such as in the function below. Note that the function assumes that the keyword provided will be exactly the same as it appears in the text.
#
# With the function `find_sentences_with_keyword()`, we will iterate through `document.sents` and pull out any sentence that contains a particular "keyword." Then we will display these sentence with the keywords bolded.

# %%
import re
from IPython.display import Markdown, display

# %%
def find_sentences_with_keyword(keyword, document):
    
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        sentence = sentence.text
        
        #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
        if keyword.lower() in sentence.lower():
            
            #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
            sentence = re.sub('\n', ' ', sentence)
            sentence = re.sub(f"{keyword}", f"**{keyword}**", sentence, flags=re.IGNORECASE)
            
            display(Markdown(sentence))

# %%
find_sentences_with_keyword(keyword="хороший", document=document)
# Out:
# и если не **хороший**, то порядочный, как говорят.

# %% [markdown]
# ## Get Keyword in Context

# %% [markdown]
# We can also find out about a keyword's more immediate context — its neighboring words to the left and right — and we can fine-tune our search with POS tagging.
#
# To do so, we will first create a list of what's called *ngrams*. "Ngrams" are any sequence of *n* tokens in a text. They're an important concept in computational linguistics and NLP. (Have you ever played with [Google's *Ngram* Viewer](https://books.google.com/ngrams)?)
#
# Below we're going to make a list of *bigrams*, that is, all the two-word combinations from the sample text. We're going to use these bigrams to find the neighboring words that appear alongside particular keywords.

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
#Make a function to get all two-word combinations
def get_bigrams(word_list, number_consecutive_words=2):
    
    ngrams = []
    adj_length_of_word_list = len(word_list) - (number_consecutive_words - 1)
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + number_consecutive_words]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
        
    return ngrams

# %%
bigrams = get_bigrams(tokens_and_labels)

# %% [markdown]
# Let's take a peek at the bigrams:

# %%
bigrams[5:20]
# Out:
# [[('так', 'ADV'), ('сделала', 'VERB')],
#  [('сделала', 'VERB'), ('что', 'SCONJ')],
#  [('что', 'SCONJ'), ('я', 'PRON')],
#  [('я', 'PRON'), ('не', 'PART')],
#  [('не', 'PART'), ('умею', 'VERB')],
#  [('умею', 'VERB'), ('жить', 'VERB')],
#  [('жить', 'VERB'), ('без', 'ADP')],
#  [('без', 'ADP'), ('нее', 'PRON')],
#  [('нее', 'PRON'), ('Это', 'PRON')],
#  [('Это', 'PRON'), ('она', 'PRON')],
#  [('она', 'PRON'), ('сделала', 'VERB')],
#  [('сделала', 'VERB'), ('я', 'PRON')],
#  [('я', 'PRON'), ('не', 'PART')],
#  [('не', 'PART'), ('виноват', 'ADJ')],
#  [('виноват', 'ADJ'), ('Я', 'PRON')]]

# %% [markdown]
# Now that we have our list of bigrams, we're going to make a function `get_neighbor_words()`. This function will return the most frequent words that appear next to a particular keyword. The function can also be fine-tuned to return neighbor words that match a certain part of speech by changing the `pos_label` parameter.

# %%
def get_neighbor_words(keyword, bigrams, pos_label = None):
    
    neighbor_words = []
    keyword = keyword.lower()
    
    for bigram in bigrams:
        
        #Extract just the lowercased words (not the labels) for each bigram
        words = [word.lower() for word, label in bigram]        
        
        #Check to see if keyword is in the bigram
        if keyword in words:
            
            for word, label in bigram:
                
                #Now focus on the neighbor word, not the keyword
                if word.lower() != keyword:
                    #If the neighbor word matches the right pos_label, append it to the master list
                    if label == pos_label or pos_label == None:
                        neighbor_words.append(word.lower())
    
    return Counter(neighbor_words).most_common()

# %%
get_neighbor_words("сад", bigrams)
# Out:
# [('в', 9),
#  ('и', 6),
#  ('не', 4),
#  ('там', 2),
#  ('как', 2),
#  ('теплый', 1),
#  ('чистый', 1),
#  ('к', 1),
#  ('мой', 1),
#  ('оживший', 1),
#  ('то', 1),
#  ('я', 1),
#  ('люблю', 1),
#  ('увидеть', 1),
#  ('весну', 1),
#  ('ix', 1),
#  ('весь', 1),
#  ('наполнялся', 1)]

# %%
get_neighbor_words("сад", bigrams, pos_label='VERB')
# Out:
# [('оживший', 1), ('люблю', 1), ('увидеть', 1), ('наполнялся', 1)]

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Try out `find_sentences_with_keyword()` and `get_neighbor_words` with your own keywords of interest.

# %%
find_sentences_with_keyword(keyword="YOUR KEY WORD", document=document)

# %%
get_neighbor_words(keyword="YOUR KEY WORD", bigrams, pos_label=None)
