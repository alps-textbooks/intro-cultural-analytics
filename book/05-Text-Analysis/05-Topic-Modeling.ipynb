# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# In the next lessons, we're going to learn about a text analysis method called *topic modeling*.
#
# This method will help us identify the main topics or discourses within a collection of texts (or within a single text that has been separated into smaller text chunks).

# %% [markdown]
# - [What is Topic Modeling?](06-Topic-Modeling-Overview.ipynb)
# - [MALLET Set Up](07-Topic-Modeling-Set-Up.ipynb)
# - [MALLET & Text Files (NYT Articles)](08-Topic-Modeling-Text-Files.ipynb)
# - [Tomotopy & Text Files (NYT Articles) - No Java required](09-Topic-Modeling-Without-Mallet.ipynb)
# - [MALLET & CSV Files (Reddit Posts)](10-Topic-Modeling-CSV.ipynb)
# - [MALLET & Time Series (Tweets)](11-Topic-Modeling-Time-Series.ipynb)
