# %% [markdown]
# # Data Collection

# %% [markdown]
# This series of lessons will focus on how to collect cultural data from the internet:
#
# - [Users' Data: Legal & Ethical Considerations](01-User-Ethics-Legal-Concerns.ipynb)
# - [Web Scraping — Part 1](02-Web-Scraping-Part1.ipynb)
# - [Web Scraping — Part 2](03-Web-Scraping-Part2.ipynb)
# - [Git and GitHub](04-Git-GitHub.ipynb)
# - [Application Programming Interfaces (APIs)](05-What-Is-API.ipynb)
# - [Song Genius Data](06-Song-Genius.ipynb)
# - [Twitter Data](10-Twitter.ipynb)
# - [Reddit Data](14-Reddit-Data.ipynb)
